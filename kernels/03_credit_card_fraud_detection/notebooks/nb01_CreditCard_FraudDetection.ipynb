# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Libraries" data-toc-modified-id="Libraries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Libraries</a></span></li><li><span><a href="#Reading-and-Exploring-the-Data" data-toc-modified-id="Reading-and-Exploring-the-Data-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Reading and Exploring the Data</a></span></li><li><span><a href="#Modeling" data-toc-modified-id="Modeling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Modeling</a></span><ul class="toc-item"><li><span><a href="#Undersampling" data-toc-modified-id="Undersampling-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Undersampling</a></span></li><li><span><a href="#Oversampling" data-toc-modified-id="Oversampling-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Oversampling</a></span></li></ul></li></ul></div>

# %% [markdown]
# The goal of this notebook is to present the step by step of developing a Machine Learning model for detecting fraud on credit card transactions. Here we will go trough to understanding the data from choosing the best model for the task.
#
# By the end, we will integrate this study with _Tableau_ for purposing an efficient way to control the metrics of a model. The idea is to build a dashboard for showing us some useful information about the model development. I'm very excited to show you this and to see if you would enjoy it. I think and hope you will.
#
# So, if you like this kernel, don't forget to **UPVOTE IT**! It really give me strength to keep doing more.

# %% [markdown]
# # Libraries

# %%
# Stsandard libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline
from datetime import datetime
import time

# Utilities
from utils.viz_utils import *
from utils.ml_utils import *
from utils.custom_transformers import *

# Pipeline
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Modeling
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import lightgbm as lgb
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, cross_val_predict, \
                                    learning_curve
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, \
    accuracy_score, precision_score, recall_score, f1_score
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE

# %% [markdown]
# # Reading and Exploring the Data

# %% [markdown]
# Let's first read the data withing a optimized approach (low memory usage)

# %%
# Data path
path = r'D:\Users\thiagoPanini\Downloads\Datasets\kgl_CreditCard_FraudDetection'
df_ori = import_data(path + r'\creditcard.csv', optimized=True)
df_ori.columns = [col.lower() for col in df_ori.columns]

# Results
print(f'Data dimension: {df_ori.shape}')
df_ori.head()
# Out:
# O dataset possui 31 colunas, das quais 31 são elegíveis a otimização.
#
# ----------------------------------------------------
# Memória RAM utilizada (50 linhas): 0.0119 MB
# Memória RAM após otimização (50 linhas): 0.0060 MB
# ----------------------------------------------------
#
# Ganho de 49.68% em uso de memória!
#
# Data dimension: (284807, 31)
#    time        v1        v2        v3        v4        v5        v6        v7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          v8        v9  ...       v21       v22       v23       v24       v25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798279 -0.137458  0.141267 -0.206010
#
#         v26       v27       v28      amount  class
# 0 -0.189115  0.133558 -0.021053  149.619995      0
# 1  0.125895 -0.008983  0.014724    2.690000      0
# 2 -0.139097 -0.055353 -0.059752  378.660004      0
# 3 -0.221929  0.062723  0.061458  123.500000      0
# 4  0.502292  0.219422  0.215153   69.989998      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ___
# * _Target class balance_
# ___

# %%
# Target class balance
fig, ax = plt.subplots(figsize=(7, 7))
label_names = ['Non-Fraud', 'Fraud']
color_list = ['darkslateblue', 'crimson']
text = f'Total\n{len(df_ori)}'
title = 'Target Class Balance'

# Visualizing it through a donut chart
donut_plot(df_ori, col='class', ax=ax, label_names=label_names, colors=color_list, title=title, text=text)

# %% [markdown]
# ___
# * _Complete overview of each feature_
# ___

# %%
df_overview = data_overview(df_ori, corr=True, label_name='class')
df_overview.head(20)
# Out:
#    feature  qtd_null  percent_null    dtype  qtd_cat  target_pearson_corr
# 0     time         0           0.0    int32        0            -0.012323
# 1      v16         0           0.0  float32        0            -0.196539
# 2   amount         0           0.0  float32        0             0.005632
# 3      v28         0           0.0  float32        0             0.009536
# 4      v27         0           0.0  float32        0             0.017580
# 5      v26         0           0.0  float32        0             0.004455
# 6      v25         0           0.0  float32        0             0.003308
# 7      v24         0           0.0  float32        0            -0.007221
# 8      v23         0           0.0  float32        0            -0.002685
# 9      v22         0           0.0  float32        0             0.000805
# 10     v21         0           0.0  float32        0             0.040413
# 11     v20         0           0.0  float32        0             0.020090
# 12     v19         0           0.0  float32        0             0.034783
# 13     v18         0           0.0  float32        0            -0.111485
# 14     v17         0           0.0  float32        0            -0.326481
# 15     v15         0           0.0  float32        0            -0.004223
# 16      v1         0           0.0  float32        0            -0.101347
# 17     v14         0           0.0  float32        0            -0.302544
# 18     v13         0           0.0  float32        0            -0.004570
# 19     v12         0           0.0  float32        0            -0.260593

# %% [markdown]
# ___
# * _Target correlation (positive and negative)_
# ___

# %%
# Creating figures and plotting correlation analysis
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(16, 8))
target_correlation_matrix(data=df_ori, label_name='class', corr='positive', ax=axs[0], cbar=False)
target_correlation_matrix(data=df_ori, label_name='class', corr='negative', ax=axs[1], cbar=False)

# Setting up titles
axs[0].set_title('Top 10 Features - $Positive$ Correlation with Target Variable', size=14, color='dimgrey', pad=20)
axs[1].set_title('Top 10 Features - $Negative$ Correlation with Target Variable', size=14, color='dimgrey', pad=20)

plt.tight_layout()
plt.show()

# %% [markdown]
# Here we can see that almos all the features don't have correlation between each other. The only exception occurs on the `amount` features. This was expected as long as the features `v1` to `v28` were created through a dimensionality reduction proccess.
#
# The thing that can be pointed here is that the strongest positive correlation with our `class` is from `v11` feature. On the other hand, we get strongest negative correlation with our `class` variable from `v17` feature. Nice.

# %%
# Building a figure with GridSpec
fig = plt.figure(constrained_layout=True, figsize=(16, 8))

# Defining GridSpec and axis
gs = GridSpec(1, 5, figure=fig)
ax1 = fig.add_subplot(gs[0, :2])
ax2 = fig.add_subplot(gs[0, 2:])

# Plot 1 - Amount statistics from non-fraud transactions
df_normal = df_ori[df_ori['class'] == 0]
df_fraud = df_ori[df_ori['class'] == 1]
normal_amount_stats = df_normal['amount'].describe()
fraud_amount_stats = df_fraud['amount'].describe()
y_ini = 0.87

# Iterating over normal transactions
for stats, value in normal_amount_stats.items():
    if stats == 'count':
        continue
    ax1.text(0.2, y_ini, 'R$ ' + str(round(value, 2)), color='mediumseagreen', ha='center', fontsize=30)
    ax1.text(0.2, y_ini - 0.05, stats.capitalize(), color='black', ha='center', fontsize=12)
    y_ini -= 0.13

# Iterating over fraudulent transactions
y_ini = 0.87
for stats, value in fraud_amount_stats.items():
    if stats == 'count':
        continue
    ax1.text(0.7, y_ini, 'R$ ' + str(round(value, 2)), color='crimson', ha='center', fontsize=30)
    ax1.text(0.7, y_ini - 0.05, stats.capitalize(), color='black', ha='center', fontsize=12)
    y_ini -= 0.13

# Setting up details
ax1.axvline(x=0.465, ymin=0.05, ymax=0.95, color='dimgrey', linestyle='--')
ax1.text(0.05, 0.98, 'Statistics for Amount on \n$Normal$ Transactions', size=12, color='dimgrey',)
ax1.text(0.55, 0.98, 'Statistics for Amount on \n$Fraud$ Transactions', size=12, color='dimgrey',)
ax1.axis('off')

# Plot 2 - Distribution over amount on fraud and normal transactions
#sns.boxplot(x='class', y='amount', data=df_ori, ax=ax2, palette=['mediumseagreen', 'crimson'], showfliers=False)
sns.kdeplot(np.log(df_normal['amount']), ax=ax2, color='mediumseagreen', shade=True, label='Log Normal')
sns.kdeplot(np.log(df_fraud['amount']), ax=ax2, color='crimson', shade=True, label='Log Fraud')
format_spines(ax2, right_border=False)
ax2.set_title('Log Distribution for Amount on $Normal$ and $Fraud$ Transactions', size=14, color='dimgrey')

plt.tight_layout()
plt.show()

# %% [markdown]
# Ok, as long as we have a deep unbalanced dataset, it's difficult to see trends on any of the features. When we take a look at the statistics of amount feature on normal and fraud transactions, it's kind of dangerous to point things like "Oh, frauds are always related to high amount transactions". In fact this is not true.
#
# Meanwhile, it's nice to see the behavior of each field on the distribution plot. For presenting this view, we applied a log transformation on amount feature.

# %% [markdown]
# ___
# * _Pré-processing Pipeline_
# ___

# %%
# Features to be used on dataprep pipeline
features_ori = list(df_ori.drop('time', axis=1).columns)

# Construction a pre-processing pipeline from columns_transformers.py
pre_processing_pipe = Pipeline([
    ('selector', FeatureSelection(features=features_ori)),
    ('dup_dropper', DropDuplicates()),
    ('splitter', SplitData(target='class'))
])

# Executing the pipeline
X_train, X_test, y_train, y_test = pre_processing_pipe.fit_transform(df_ori)
model_features = list(X_train.columns)

# Looking at the results
print(f'Dimensões de X_train: {X_train.shape}')
print(f'Dimensões de y_train: {y_train.shape}')
print(f'\nDimensões de X_test: {X_test.shape}')
print(f'Dimensões de y_test: {y_test.shape}')
# Out:
# Dimensões de X_train: (220530, 29)
# Dimensões de y_train: (220530,)
#
# Dimensões de X_test: (55133, 29)
# Dimensões de y_test: (55133,)

# %%
# Splitting the data by the dtype
num_attribs, cat_attribs = split_cat_num_data(X_train)
print(f'Total of numerical features: {len(num_attribs)}')
print(f'Total of categorical features: {len(cat_attribs)}')
# Out:
# Total of numerical features: 29
# Total of categorical features: 0

# %% [markdown]
# # Modeling

# %% [markdown]
# ___
# * _Models: LogisticRegression, DecisionTrees, RandomForest and LightGBM_
# ___

# %%
# Preparing a dictionary to feed the ClassifiersAnalysis class
set_prep = {
    'X_train_prep': X_train.values,
    'X_test_prep': X_test.values,
    'y_train': y_train,
    'y_test': y_test
}

# %%
# Logistic Regression hyperparameters
logreg_param_grid = {
    'C': np.linspace(0.1, 10, 20),
    'penalty': ['l1', 'l2'],
    'class_weight': ['balanced', None],
    'random_state': [42],
    'solver': ['liblinear']
}

# Decision Trees hyperparameters
tree_param_grid = {
    'criterion': ['entropy', 'gini'],
    'max_depth': [3, 5, 10, 20],
    'max_features': np.arange(1, X_train.shape[1]),
    'class_weight': ['balanced', None],
    'random_state': [42]
}

# Random Forest hyperparameters
forest_param_grid = {
    'bootstrap': [True, False],
    'max_depth': [3, 5, 10, 20, 50],
    'n_estimators': [50, 100, 200, 500],
    'random_state': [42],
    'max_features': ['auto', 'sqrt'],
    'class_weight': ['balanced', None]
}

# LightGBM hyperparameters
lgbm_param_grid = {
    'num_leaves': list(range(8, 92, 4)),
    'min_data_in_leaf': [10, 20, 40, 60, 100],
    'max_depth': [3, 4, 5, 6, 8, 12, 16],
    'learning_rate': [0.1, 0.05, 0.01, 0.005],
    'bagging_freq': [3, 4, 5, 6, 7],
    'bagging_fraction': np.linspace(0.6, 0.95, 10),
    'reg_alpha': np.linspace(0.1, 0.95, 10),
    'reg_lambda': np.linspace(0.1, 0.95, 10),
}

lgbm_fixed_params = {
    'application': 'binary',
    'objective': 'binary',
    'metric': 'auc',
    'is_unbalance': 'true',
    'boosting_type': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.5,
    'bagging_fraction': 0.5,
    'bagging_freq': 20,
    'learning_rate': 0.05,
    'verbose': 0
}

# %%
# Preparando set de classificadores
set_classifiers = {
    'LogisticRegression': {
        'model': LogisticRegression(),
        'params': logreg_param_grid
    },
    'DecisionTrees': {
        'model': DecisionTreeClassifier(),
        'params': tree_param_grid
    },
    'RandomForest': {
        'model': RandomForestClassifier(),
        'params': forest_param_grid
    },
    'LightGBM': {
        'model': lgb.LGBMClassifier(**lgbm_fixed_params),
        'params': lgbm_param_grid
    }
}

# %% [markdown]
# ___
# * _Training each model selected with RandomizedSearchCV_
# ___

# %%
# Instanciando classe e treinando set de classificadores
clf_tool = BinaryClassifiersAnalysis()
clf_tool.fit(set_classifiers, X_train, y_train, random_search=True, cv=5, verbose=5)
# Out:
# Treinando modelo LogisticRegression
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:  4.2min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 16.2min finished
# Treinando modelo DecisionTrees
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.9min finished
# Treinando modelo RandomForest
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed: 13.7min
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed: 76.8min finished
# Treinando modelo LightGBM
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   25.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  1.9min finished

# %% [markdown]
# ___
# * _Evaluating on training and test data_
# ___

# %%
df_performances = clf_tool.evaluate_performance(X_train, y_train, X_test, y_test, cv=5)
cm = sns.light_palette('cornflowerblue', as_cmap=True)
df_performances.reset_index(drop='True').style.background_gradient(cmap=cm)
# Out:
# Avaliando performance do modelo LogisticRegression
#
# Avaliando performance do modelo DecisionTrees
#
# Avaliando performance do modelo RandomForest
#
# Avaliando performance do modelo LightGBM
# <style  type="text/css" >
#     #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col2 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col3 {
#             background-color:  #d2e0fa;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col4 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col5 {
#             background-color:  #cadbf9;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col6 {
#             background-color:  #6c9bee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col7 {
#             background-color:  #d4e2fa;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col2 {
#             background-color:  #e7effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col3 {
#             background-color:  #d3e1fa;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col4 {
#             background-color:  #6898ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col5 {
#             background-color:  #ccdcf9;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col6 {
#             background-color:  #739fef;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row1_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col2 {
#             background-color:  #80a8f0;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col3 {
#             background-color:  #a5c1f5;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col4 {
#             background-color:  #709eee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col5 {
#             background-color:  #99baf3;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col6 {
#             background-color:  #dae6fb;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row2_col7 {
#             background-color:  #e3ecfc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col2 {
#             background-color:  #95b7f3;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col3 {
#             background-color:  #bdd2f7;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col4 {
#             background-color:  #719eef;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col5 {
#             background-color:  #b2caf6;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col6 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row3_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col2 {
#             background-color:  #6999ee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col3 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col4 {
#             background-color:  #6a99ee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col5 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col6 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row4_col7 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col2 {
#             background-color:  #6c9aee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col3 {
#             background-color:  #78a2ef;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col4 {
#             background-color:  #709dee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col5 {
#             background-color:  #739fef;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col6 {
#             background-color:  #739fef;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row5_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col2 {
#             background-color:  #6595ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col3 {
#             background-color:  #6b9aee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col4 {
#             background-color:  #e7eefc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col5 {
#             background-color:  #e2ebfc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col6 {
#             background-color:  #6998ee;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row6_col7 {
#             background-color:  #e6eefc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col2 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col3 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col4 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col5 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col6 {
#             background-color:  #7fa7f0;
#             color:  #000000;
#         }    #T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row7_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }</style><table id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >model</th>        <th class="col_heading level0 col1" >approach</th>        <th class="col_heading level0 col2" >acc</th>        <th class="col_heading level0 col3" >precision</th>        <th class="col_heading level0 col4" >recall</th>        <th class="col_heading level0 col5" >f1</th>        <th class="col_heading level0 col6" >auc</th>        <th class="col_heading level0 col7" >total_time</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col0" class="data row0 col0" >LogisticRegression</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col1" class="data row0 col1" >Treino 5 K-folds</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col2" class="data row0 col2" >0.9773</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col3" class="data row0 col3" >0.0653</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col4" class="data row0 col4" >0.9083</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col5" class="data row0 col5" >0.1219</td>
#                         <td id="T_cc26cbf8_b95a_11ea_95b9_d46a6af96bb4row0_col6" class="data row0 col6" >0.9743</td>

# %% [markdown]
# ___
# * _Looking at the feature importance of a specific model_
# ___

# %%
fig, ax = plt.subplots(figsize=(13, 12))
lgbm_feature_importance = clf_tool.feature_importance_analysis(model_features, specific_model='LightGBM', ax=ax)
plt.show()

# %% [markdown]
# ___
# * _ROC Curve for training and testing data_
# ___

# %%
clf_tool.plot_roc_curve()

# %% [markdown]
# ___
# * _Score distributions on training and testing data_
# ___

# %%
clf_tool.plot_score_distribution('LightGBM')

# %% [markdown]
# ___
# * _Splitting the probabilities on bins_
# ___

# %%
# Separação por faixa
clf_tool.plot_score_bins('LightGBM', bin_range=0.1)

# %% [markdown]
# ## Undersampling

# %%
# Applying undersampling
rus = RandomUnderSampler()
X_train_under, y_train_under = rus.fit_sample(X_train, y_train)

# Training new classifiers using undersampling
undersamp_approach= '_undersamp'
clf_tool.fit(set_classifiers, X_train_under, y_train_under, random_search=True, cv=5, approach=undersamp_approach)
# Out:
# Treinando modelo LogisticRegression_undersamp
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.5s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.1s
# Treinando modelo DecisionTrees_undersamp
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Done  32 out of  50 | elapsed:    0.1s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    0.2s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# Treinando modelo RandomForest_undersamp
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    8.1s finished
# Treinando modelo LightGBM_undersamp
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    4.0s finished

# %% [markdown]
# ___
# * _Evaluating on training and test data_
# ___

# %%
df_performances = clf_tool.evaluate_performance(X_train_under, y_train_under, X_test, y_test)
cm = sns.light_palette('cornflowerblue', as_cmap=True)
df_performances.reset_index(drop='True').style.background_gradient(cmap=cm)
# Out:
# Avaliando performance do modelo LogisticRegression_undersamp
#
# Avaliando performance do modelo DecisionTrees_undersamp
#
# Avaliando performance do modelo RandomForest_undersamp
#
# Avaliando performance do modelo LightGBM_undersamp
# <style  type="text/css" >
#     #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col2 {
#             background-color:  #8db1f2;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col3 {
#             background-color:  #dfe9fb;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col4 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col5 {
#             background-color:  #d7e4fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col6 {
#             background-color:  #6f9cee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row0_col7 {
#             background-color:  #d4e2fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col2 {
#             background-color:  #8cb1f2;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col3 {
#             background-color:  #e0eafb;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col4 {
#             background-color:  #6898ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col5 {
#             background-color:  #d8e4fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col6 {
#             background-color:  #75a1ef;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row1_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col2 {
#             background-color:  #6d9bee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col3 {
#             background-color:  #cdddf9;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col4 {
#             background-color:  #709eee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col5 {
#             background-color:  #bbd1f7;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col6 {
#             background-color:  #dbe6fb;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row2_col7 {
#             background-color:  #e3ecfc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col2 {
#             background-color:  #739fef;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col3 {
#             background-color:  #d7e4fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col4 {
#             background-color:  #719eef;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col5 {
#             background-color:  #c9daf9;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col6 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row3_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col2 {
#             background-color:  #6696ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col3 {
#             background-color:  #b3cbf6;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col4 {
#             background-color:  #6a99ee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col5 {
#             background-color:  #9cbcf4;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col6 {
#             background-color:  #6797ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row4_col7 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col2 {
#             background-color:  #6696ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col3 {
#             background-color:  #bbd1f7;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col4 {
#             background-color:  #709dee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col5 {
#             background-color:  #a5c2f5;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col6 {
#             background-color:  #75a1ef;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row5_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col2 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col3 {
#             background-color:  #b6cdf7;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col4 {
#             background-color:  #e7eefc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col5 {
#             background-color:  #e5edfc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col6 {
#             background-color:  #6b9aee;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row6_col7 {
#             background-color:  #e6eefc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col2 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col3 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col4 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col5 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col6 {
#             background-color:  #81a9f0;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row7_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col2 {
#             background-color:  #d4e2fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col3 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col4 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col5 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col6 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row8_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col2 {
#             background-color:  #8cb1f2;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col3 {
#             background-color:  #e0eafb;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col4 {
#             background-color:  #6898ed;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col5 {
#             background-color:  #d8e4fa;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col6 {
#             background-color:  #79a4ef;
#             color:  #000000;
#         }    #T_0a4db4c8_b966_11ea_b6fd_d46a6af96bb4row9_col7 {
#             background-color:  #e8effc;
#             color:  #000000;

# %% [markdown]
# ___
# * _ROC Curve for training and testing data_
# ___

# %%
clf_tool.plot_roc_curve()

# %% [markdown]
# ___
# * _Score distributions on training and testing data_
# ___

# %%
clf_tool.plot_score_distribution('LightGBM_undersamp')

# %% [markdown]
# ___
# * _Splitting the probabilities on bins_
# ___

# %%
clf_tool.plot_score_bins('LightGBM_undersamp', bin_range=0.1)

# %% [markdown]
# ## Oversampling

# %% [markdown]
# Let's change the set_classifiers dictionary to optimize time

# %%
lgbm_set_classifier = {}
lgbm_set_classifier['LightGBM'] = set_classifiers['LightGBM']

# %%
# Applying oversampling
sm = SMOTE(sampling_strategy='minority', random_state=42)
X_train_over, y_train_over = sm.fit_sample(X_train, y_train)

# Treinando novo modelo após undersampling
oversamp_approach= '_oversamp'
clf_tool.fit(lgbm_set_classifier, X_train_over, y_train_over, random_search=True, cv=5, approach=oversamp_approach)
# Out:
# Treinando modelo LightGBM_oversamp
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:   40.0s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:  3.2min finished

# %% [markdown]
# ___
# * _Evaluating on training and test data_
# ___

# %%
df_performances = clf_tool.evaluate_performance(X_train_over, y_train_over, X_test, y_test)
cm = sns.light_palette('cornflowerblue', as_cmap=True)
df_performances.reset_index(drop='True').style.background_gradient(cmap=cm)
# Out:
# Avaliando performance do modelo LightGBM_oversamp
# <style  type="text/css" >
#     #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col2 {
#             background-color:  #8db1f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col3 {
#             background-color:  #e0eafb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col4 {
#             background-color:  #709dee;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col5 {
#             background-color:  #d8e4fa;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col6 {
#             background-color:  #86acf1;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row0_col7 {
#             background-color:  #d4e2fa;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col2 {
#             background-color:  #8cb1f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col3 {
#             background-color:  #e0eafb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col4 {
#             background-color:  #74a0ef;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col5 {
#             background-color:  #d9e5fb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col6 {
#             background-color:  #8bb0f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row1_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col2 {
#             background-color:  #6d9bee;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col3 {
#             background-color:  #ceddf9;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col4 {
#             background-color:  #7ba5f0;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col5 {
#             background-color:  #bed2f7;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col6 {
#             background-color:  #dde8fb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row2_col7 {
#             background-color:  #e3ecfc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col2 {
#             background-color:  #739fef;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col3 {
#             background-color:  #d8e4fa;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col4 {
#             background-color:  #7ca6f0;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col5 {
#             background-color:  #cbdcf9;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col6 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row3_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col2 {
#             background-color:  #6696ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col3 {
#             background-color:  #b4ccf6;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col4 {
#             background-color:  #75a1ef;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col5 {
#             background-color:  #a1bff4;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col6 {
#             background-color:  #7fa8f0;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row4_col7 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col2 {
#             background-color:  #6696ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col3 {
#             background-color:  #bcd1f7;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col4 {
#             background-color:  #7ba5f0;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col5 {
#             background-color:  #a9c4f5;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col6 {
#             background-color:  #8bb0f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row5_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col2 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col3 {
#             background-color:  #b7cef7;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col4 {
#             background-color:  #e7eefc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col5 {
#             background-color:  #e5edfc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col6 {
#             background-color:  #84abf1;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row6_col7 {
#             background-color:  #e6eefc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col2 {
#             background-color:  #6495ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col3 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col4 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col5 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col6 {
#             background-color:  #95b7f3;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row7_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col2 {
#             background-color:  #d4e2fa;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col3 {
#             background-color:  #6797ed;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col4 {
#             background-color:  #709dee;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col5 {
#             background-color:  #6c9aee;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col6 {
#             background-color:  #7da6f0;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row8_col7 {
#             background-color:  #e8effc;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col2 {
#             background-color:  #8cb1f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col3 {
#             background-color:  #e0eafb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col4 {
#             background-color:  #74a0ef;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col5 {
#             background-color:  #d9e5fb;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col6 {
#             background-color:  #8fb2f2;
#             color:  #000000;
#         }    #T_1a4d431c_b967_11ea_a000_d46a6af96bb4row9_col7 {
#             background-color:  #e8effc;
#             color:  #000000;

# %% [markdown]
# ___
# * _ROC Curve for training and testing data_
# ___

# %%
clf_tool.plot_roc_curve()

# %% [markdown]
# ___
# * _Score distributions on training and testing data_
# ___

# %%
clf_tool.plot_score_distribution('LightGBM_oversamp')

# %% [markdown]
# ___
# * _Splitting the probabilities on bins_
# ___

# %%
clf_tool.plot_score_bins('LightGBM_oversamp', bin_range=0.1)

# %% [markdown]
# Filtering the model/approach with highest AUC on test data:

# %%
df_performances.query('approach == "Teste"').sort_values(by='auc', ascending=False)
# Out:
#                           model approach     acc  precision  recall      f1  \
# 0             LightGBM_oversamp    Teste  0.9978     0.4130  0.8352  0.5527
# 0            LightGBM_undersamp    Teste  0.9750     0.0553  0.8791  0.1041
# 0            LogisticRegression    Teste  0.9775     0.0612  0.8791  0.1144
# 0                  RandomForest    Teste  0.9970     0.3319  0.8242  0.4732
# 0  LogisticRegression_undersamp    Teste  0.9775     0.0610  0.8791  0.1140
# 0        RandomForest_undersamp    Teste  0.9690     0.0450  0.8791  0.0856
# 0                      LightGBM    Teste  0.9983     0.0000  0.0000  0.0000
# 0       DecisionTrees_undersamp    Teste  0.9751     0.0530  0.8352  0.0997
# 0                 DecisionTrees    Teste  0.9905     0.1274  0.8132  0.2202
#
#       auc  total_time
# 0  0.9790       0.915
# 0  0.9722       0.530
# 0  0.9706       0.354
# 0  0.9706       1.461
# 0  0.9679       0.076
# 0  0.9679       1.917
# 0  0.9632       0.531
# 0  0.9319       0.054
# 0  0.9017       0.081
