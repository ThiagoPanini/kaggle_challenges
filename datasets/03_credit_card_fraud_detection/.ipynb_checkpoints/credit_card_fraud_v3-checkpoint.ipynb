# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Explorando-Dados" data-toc-modified-id="Explorando-Dados-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Explorando Dados</a></span><ul class="toc-item"><li><span><a href="#Valores-Transacionais" data-toc-modified-id="Valores-Transacionais-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Valores Transacionais</a></span></li><li><span><a href="#Tempo-entre-Transações" data-toc-modified-id="Tempo-entre-Transações-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Tempo entre Transações</a></span></li><li><span><a href="#Valores-Iguais" data-toc-modified-id="Valores-Iguais-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Valores Iguais</a></span></li><li><span><a href="#Valores-Acima-da-Média" data-toc-modified-id="Valores-Acima-da-Média-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Valores Acima da Média</a></span></li><li><span><a href="#Normalizando-Dados" data-toc-modified-id="Normalizando-Dados-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Normalizando Dados</a></span></li></ul></li><li><span><a href="#Separando-os-Dados" data-toc-modified-id="Separando-os-Dados-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Separando os Dados</a></span></li><li><span><a href="#Under-Sampling" data-toc-modified-id="Under-Sampling-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Under-Sampling</a></span><ul class="toc-item"><li><span><a href="#Separando-os-Dados-(Under-Sampling)" data-toc-modified-id="Separando-os-Dados-(Under-Sampling)-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Separando os Dados (Under-Sampling)</a></span></li><li><span><a href="#Avaliando-Modelos-Candidatos" data-toc-modified-id="Avaliando-Modelos-Candidatos-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Avaliando Modelos Candidatos</a></span><ul class="toc-item"><li><span><a href="#Treino-Under-Sampling" data-toc-modified-id="Treino-Under-Sampling-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Treino Under Sampling</a></span></li><li><span><a href="#Teste-Under-Sampling" data-toc-modified-id="Teste-Under-Sampling-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Teste Under Sampling</a></span></li><li><span><a href="#Teste-Original" data-toc-modified-id="Teste-Original-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Teste Original</a></span></li><li><span><a href="#ROC-Curve" data-toc-modified-id="ROC-Curve-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>ROC Curve</a></span></li><li><span><a href="#Precision-x-Recall" data-toc-modified-id="Precision-x-Recall-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Precision x Recall</a></span></li></ul></li></ul></li><li><span><a href="#Regressão-Logística" data-toc-modified-id="Regressão-Logística-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Regressão Logística</a></span><ul class="toc-item"><li><span><a href="#Under-Sampled" data-toc-modified-id="Under-Sampled-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Under-Sampled</a></span></li></ul></li></ul></div>

# %% [markdown]
# Este notebook é responsável por alocar o desenvolvimento e a investigação de um conjunto de dados do [Kaggle](https://www.kaggle.com/) contendo informações sobre transações de cartões de crédito para [identificação de fraude](https://www.kaggle.com/mlg-ulb/creditcardfraud).

# %% [markdown]
# <img src="credit_card_fraud_background.png" alt="Credit Card Fraud Background" style="width: 750px;"/>

# %% [markdown]
# No contexto desse problema de identificação de transações fraudulentas relacionadas ao uso de cartões de crédito, temos um conjunto de dados exemplificando transações realizadas durante dois dias de Setembro de 2013 por titulares europeus. Os dados foram coletados apresentam 492 transações fraudulentas em um total de 284.807 amostras. Isto mostra que o conjunto é altamente desbalanceado, apresentando exemplos da classe positiva (fraude) em apenas 0.172% do total de transações.
#
# Além disso, temos um total 30 features onde 28 delas foram geradas a partir de um procedimento de PCA e, por critérios de segurança e sigilo, não foram providas informações adicionais sobre as mesmas. As duas features restantes representam, respectivamente:
#
# * **Time:** Segundos entre cada transação e a primeira transação do dataset;
# * **Amount:** Valor da Transação.
#
# Para avaliação do modelo, é recomendado o uso de AUC ROC (Area Under the Curve - ROC), uma vez que acurácias por matriz de confusão não são boas em dados desbalanceados.

# %% [markdown]
# # Funções

# %%
import matplotlib
def plot_roc_curve(fpr, tpr, y, y_scores, auc, label=None):
    """docstring for plot_roc_curve:
    function responsible for plot the ROC curve of a model
    
    input:
        fpr: false positive rate
        tpr: true positive rate"""
    
    # Showing data
    sns.set(style='white', palette='muted', color_codes=True)
    plt.plot(fpr, tpr, linewidth=2, label=f'{label}, auc={auc:.2f}')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.axis([-0.02, 1.02, -0.02, 1.02])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'ROC Curve', size=14)
    plt.legend()

# %%
def plot_precision_vs_recall(precisions, recalls, label=None):
    sns.set(style='white', palette='muted', color_codes=True)
    plt.plot(recalls, precisions, 'b-', linewidth=1, label=label)
    plt.title('Precision versus Recall', fontsize=14)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.axis([0, 1, 0, 1])
    plt.legend()

# %% [markdown]
# ## Explorando Dados

# %%
# Importando biblioteca
import pandas as pd

# Lendo dados
df = pd.read_csv('creditcard.csv')

# Verificando
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %%
# Verificando quantidades
df.shape
# Out:
# (284807, 31)

# %%
print(f'O dataset contém {df.shape[0]} linhas e {df.shape[1]} colunas.')
# Out:
# O dataset contém 284807 linhas e 31 colunas.

# %%
# Dados nulos
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# Com o objetivo de familiarização com o dataset, vamos aplicar, nas próximas sessões, algumas investigações exploratórias relacionadas as duas features presentes no modelo que não passaram pelo procedimento de redução de dimensionalidade: `Time` e `Amount`. Os assuntos abordados serão relacionados a:
#
# * **Valores Transacionais:**
#     - Existe alguma relação entre transações com valores nulos e fraudes?
#     - Valor médio em transações normais e fraudulentas;
#     - Distribuição de valores por tipo de transação;
#
#
# * **Tempo entre Transações:**
#     - Mais de uma transação pode ter sido registrada no mesmo instante de tempo?
#     - Existe alguma relação entre transações registrada no mesmo instante e fraude?
#     - Distribuição de tempo entre transações por classe.
#
#
# * **Valores Iguais:**
#     - Existe alguma relação entre valores iguais e fraude?
#
#
# * **Valores Acima da Média:**
#     - Existe alguma relação entre valores elevados e fraude?

# %% [markdown]
# ### Valores Transacionais

# %%
# Estatísticas sobre o Valor
df['Amount'].describe()
# Out:
# count    284807.000000
# mean         88.349619
# std         250.120109
# min           0.000000
# 25%           5.600000
# 50%          22.000000
# 75%          77.165000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# O espectro de valores vai desde transações com $\$0,00$ até transações de $\$25.691,16$. O valor médio é de $\$88,34$

# %% [markdown]
# Apenas por curiosidade, vamos investigar quantas transações possuem valor nulo ($\$0,00$)

# %%
# Transações zeradas
zero_amount = df[df['Amount']==0]
zero_amount.head()
# Out:
#       Time        V1        V2        V3        V4        V5        V6  \
# 383  282.0 -0.356466  0.725418  1.971749  0.831343  0.369681 -0.107776
# 514  380.0 -1.299837  0.881817  1.452842 -1.293698 -0.025105 -1.170103
# 534  403.0  1.237413  0.512365  0.687746  1.693872 -0.236323 -0.650232
# 541  406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 575  430.0 -1.860258 -0.629859  0.966570  0.844632  0.759983 -1.481173
#
#            V7        V8        V9  ...         V21       V22       V23  \
# 383  0.751610 -0.120166 -0.420675  ...    0.020804  0.424312 -0.015989
# 514  0.861610 -0.193934  0.592001  ...   -0.272563 -0.360853  0.223911
# 534  0.118066 -0.230545 -0.808523  ...   -0.077543 -0.178220  0.038722
# 541 -2.537387  1.391657 -2.770089  ...    0.517232 -0.035049 -0.465211
# 575 -0.509681  0.540722 -0.733623  ...    0.268028  0.125515 -0.225029
#
#           V24       V25       V26       V27       V28  Amount  Class
# 383  0.466754 -0.809962  0.657334 -0.043150 -0.046401     0.0      0
# 514  0.598930 -0.397705  0.637141  0.234872  0.021379     0.0      0
# 534  0.471218  0.289249  0.871803 -0.066884  0.012986     0.0      0
# 541  0.320198  0.044519  0.177840  0.261145 -0.143276     0.0      1
# 575  0.586664 -0.031598  0.570168 -0.043007 -0.223739     0.0      0
#
# [5 rows x 31 columns]

# %%
# Quantas transações com valor zerado?
zero_amount.shape[0]
# Out:
# 1825

# %% [markdown]
# Algum insight pode ser tirado de transações fraudulentas sem nenhum valor envolvido?

# %%
# Transações zeradas e fraudulentas
zero_amount_fraud = zero_amount[zero_amount['Class']==1]
zero_amount_fraud.head()
# Out:
#           Time         V1        V2         V3        V4        V5        V6  \
# 541      406.0  -2.312227  1.951992  -1.609851  3.997906 -0.522188 -1.426545
# 8842   12093.0  -4.696795  2.693867  -4.475133  5.467685 -1.556758 -1.549420
# 23308  32686.0   0.287953  1.728735  -1.652173  3.813544 -1.090927 -0.984745
# 42756  41233.0 -10.645800  5.918307 -11.671043  8.807369 -7.975501 -3.586806
# 69980  53658.0  -1.739341  1.344521  -0.534379  3.195291 -0.416196 -1.261961
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 541    -2.537387  1.391657 -2.770089  ...    0.517232 -0.035049 -0.465211
# 8842   -4.104215  0.553934 -1.498468  ...    0.573898 -0.080163  0.318408
# 23308  -2.202318  0.555088 -2.033892  ...    0.262202 -0.633528  0.092891
# 42756 -13.616797  6.428169 -7.368451  ...    2.571970  0.206809 -1.667801
# 69980  -2.340991  0.713004 -1.416265  ...    0.383180 -0.213952 -0.336640
#
#             V24       V25       V26       V27       V28  Amount  Class
# 541    0.320198  0.044519  0.177840  0.261145 -0.143276     0.0      1
# 8842  -0.245862  0.338238  0.032271 -1.508458  0.608075     0.0      1
# 23308  0.187613  0.368708 -0.132474  0.576561  0.309843     0.0      1
# 42756  0.558419 -0.027898  0.354254  0.273329 -0.152908     0.0      1
# 69980  0.237076  0.246003 -0.044228  0.510729  0.220952     0.0      1
#
# [5 rows x 31 columns]

# %%
# Quantas?
zero_amount_fraud.shape[0]
# Out:
# 27

# %% [markdown]
# Interessante pensar em transações com valores zerados. Mais interessante ainda é pensar em transações zeradas **e** fraudulentas. Qual seria a respectiva porcentagem do total?

# %%
# Total de transações fraudulentas
df['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# Porcentagem de transações zeradas e fraudulentas
total_fraud = df['Class'].value_counts()[1]
total_zero_amount_fraud = zero_amount_fraud.shape[0]

perc_zero_amount_fraud = total_zero_amount_fraud / total_fraud
print(f'Do total de fraudes, temos {100*perc_zero_amount_fraud:.2f}% com valor \
$0,00 nas transações.')
# Out:
# Do total de fraudes, temos 5.49% com valor $0,00 nas transações.

# %% [markdown]
# Um número considerável? Precisamos entender, em primeiro lugar, o que seriam transações com valores nulos.

# %% [markdown]
# Vamos tentar retirar algum insight de transações de classes positiva (fraudulentas) e negativas (normal).

# %%
# Indexando dataframe
fraud_transactions = df.query('Class == 1')
normal_transactions = df.query('Class == 0')

# %%
# O número de amostras bate?
print(f'Transações fraudulentas: {fraud_transactions.shape[0]}')
print(f'Transações normais: {normal_transactions.shape[0]}')
# Out:
# Transações fraudulentas: 492
# Transações normais: 284315

# %%
# Estatísticas sobre valores de transações fraudulentas
fraud_transactions['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# Estatística sobre valores de transações normais
normal_transactions['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Numericamente, é possível afirmar que a média de valores de transações consideradas normais, é de $\$88.29$, enquanto o valor médio de transações fraudulentas é de $\$122.21$

# %%
# Visualizando graficamente
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %matplotlib inline

# Preparando gráfico
fig, ax = plt.subplots()
sns.set(style='darkgrid', palette='muted')
ax = sns.violinplot(x='Amount', data=fraud_transactions)
ax.set_title('Distribuição de Valores em Fraudes', size=14)
plt.show()

# %% [markdown]
# Os valores não são balanceados, ou seja, temos uma concentração de transações entre 0 e 250, mas também temos valores elevados de transações, dificultando assim a visualização gráfica. Vamos ver a distribuição de valores de transações fraudulentas.

# %%
# Boxplot
fig, ax = plt.subplots()
ax = sns.boxplot(fraud_transactions['Amount'])
ax.set_title('Distribuição de Valores em Fraudes', size=14)
plt.show()

# %% [markdown]
# Realmente fica difícil de visualizar um comportamento relacionado ao valor das transações graficamente.

# %%
# Visualizando valor médio
def format_spines(ax, right_border=True):
    """docstring for format_spines:
    função responsável por retirar bordas do gráfico e personalizar cor:
    input:
        ax: eixo do gráfico"""
    
    ax.spines['bottom'].set_color('#CCCCCC')
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['top'].set_color('#FFFFFF')
    if right_border:
        ax.spines['right'].set_color('#CCCCCC')
    else:
        ax.spines['right'].set_color('#FFFFFF')
    ax.patch.set_facecolor('#FFFFFF')
    
custom_colors = ["#3498db", "#C8391A"]
fig, ax = plt.subplots()
ax = sns.barplot(x='Class', y='Amount', data=df,
                 palette=custom_colors, ci=None)
format_spines(ax, right_border=False)
ax.set_title('Valor Médio por Tipo de Transação', size=14)

ncount = len(df)
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('${:.2f}'.format(y), (x.mean(), y), 
            ha='center', va='bottom') # set the alignment of the text
plt.tight_layout()
plt.subplots_adjust(top=1.1)
ax.set_xticklabels(['Normal', 'Fraude'])
plt.show()

# %% [markdown]
# ### Tempo entre Transações

# %% [markdown]
# Vamos investigar se há um padrão de "tempo" em transações fraudulentas respondendo a pergunta: _Transações fraudulentas ocorrem de tempos em tempos? Se sim, aproximadamente qual o padrão temporal identificado?_

# %%
# Transações fraudulentas
fraud_transactions.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 541    406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623    472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920  4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108  6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329  7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
#
#             V7        V8        V9  ...         V21       V22       V23  \
# 541  -2.537387  1.391657 -2.770089  ...    0.517232 -0.035049 -0.465211
# 623   0.325574 -0.067794 -0.270953  ...    0.661696  0.435477  1.375966
# 4920  0.562320 -0.399147 -0.238253  ...   -0.294166 -0.932391  0.172726
# 6108 -3.496197 -0.248778 -0.247768  ...    0.573574  0.176968 -0.436207
# 6329  1.713445 -0.496358 -1.282858  ...   -0.379068 -0.704181 -0.656805
#
#            V24       V25       V26       V27       V28  Amount  Class
# 541   0.320198  0.044519  0.177840  0.261145 -0.143276    0.00      1
# 623  -0.293803  0.279798 -0.145362 -0.252773  0.035764  529.00      1
# 4920 -0.087330 -0.156114 -0.542628  0.039566 -0.153029  239.93      1
# 6108 -0.053502  0.252405 -0.657488 -0.827136  0.849573   59.00      1
# 6329 -1.632653  1.488901  0.566797 -0.010016  0.146793    1.00      1
#
# [5 rows x 31 columns]

# %%
# Índices de transações fraudulentas no dataset
fraud_idx = list(fraud_transactions.index)
print(fraud_idx, end=',')
# Out:
# [541, 623, 4920, 6108, 6329, 6331, 6334, 6336, 6338, 6427, 6446, 6472, 6529, 6609, 6641, 6717, 6719, 6734, 6774, 6820, 6870, 6882, 6899, 6903, 6971, 8296, 8312, 8335, 8615, 8617, 8842, 8845, 8972, 9035, 9179, 9252, 9487, 9509, 10204, 10484, 10497, 10498, 10568, 10630, 10690, 10801, 10891, 10897, 11343, 11710, 11841, 11880, 12070, 12108, 12261, 12369, 14104, 14170, 14197, 14211, 14338, 15166, 15204, 15225, 15451, 15476, 15506, 15539, 15566, 15736, 15751, 15781, 15810, 16415, 16780, 16863, 17317, 17366, 17407, 17453, 17480, 18466, 18472, 18773, 18809, 20198, 23308, 23422, 26802, 27362, 27627, 27738, 27749, 29687, 30100, 30314, 30384, 30398, 30442, 30473, 30496, 31002, 33276, 39183, 40085, 40525, 41395, 41569, 41943, 42007, 42009, 42473, 42528, 42549, 42590, 42609, 42635, 42674, 42696, 42700, 42741, 42756, 42769, 42784, 42856, 42887, 42936, 42945, 42958, 43061, 43160, 43204, 43428, 43624, 43681, 43773, 44001, 44091, 44223, 44270, 44556, 45203, 45732, 46909, 46918, 46998, 47802, 48094, 50211, 50537, 52466, 52521, 52584, 53591, 53794, 55401, 56703, 57248, 57470, 57615, 58422, 58761, 59539, 61787, 63421, 63634, 64329, 64411, 64460, 68067, 68320, 68522, 68633, 69498, 69980, 70141, 70589, 72757, 73784, 73857, 74496, 74507, 74794, 75511, 76555, 76609, 76929, 77099, 77348, 77387, 77682, 79525, 79536, 79835, 79874, 79883, 80760, 81186, 81609, 82400, 83053, 83297, 83417, 84543, 86155, 87354, 88258, 88307, 88876, 88897, 89190, 91671, 92777, 93424, 93486, 93788, 94218, 95534, 95597, 96341, 96789, 96994, 99506, 100623, 101509, 102441, 102442, 102443, 102444, 102445, 102446, 102782, 105178, 106679, 106998, 107067, 107637, 108258, 108708, 111690, 112840, 114271, 116139, 116404, 118308, 119714, 119781, 120505, 120837, 122479, 123141, 123201, 123238, 123270, 123301, 124036, 124087, 124115, 124176, 125342, 128479, 131272, 135718, 137705, 140786, 141257, 141258, 141259, 141260, 142405, 142557, 143188, 143333, 143334, 143335, 143336, 143728, 143731, 144104, 144108, 144754, 145800, 146790, 147548, 147605, 149145, 149357, 149522, 149577, 149587, 149600, 149869, 149874, 150601, 150644, 150647, 150654, 150660, 150661, 150662, 150663, 150665, 150666, 150667, 150668, 150669, 150677, 150678, 150679, 150680, 150684, 150687, 150692, 150697, 150715, 150925, 151006, 151007, 151008, 151009, 151011, 151103, 151196, 151462, 151519, 151730, 151807, 152019, 152223, 152295, 153823, 153835, 153885, 154234, 154286, 154371, 154454, 154587, 154633, 154668, 154670, 154676, 154684, 154693, 154694, 154697, 154718, 154719, 154720, 154960, 156988, 156990, 157585, 157868, 157871, 157918, 163149, 163586, 167184, 167305, 172787, 176049, 177195, 178208, 181966, 182992, 183106, 184379, 189587, 189701, 189878, 190368, 191074, 191267, 191359, 191544, 191690, 192382, 192529, 192584, 192687, 195383, 197586, 198868, 199896, 201098, 201601, 203324, 203328, 203700, 204064, 204079, 204503, 208651, 212516, 212644, 213092, 213116, 214662, 214775, 215132, 215953, 215984, 218442, 219025, 219892, 220725, 221018, 221041, 222133, 222419, 223366, 223572, 223578, 223618, 226814, 226877, 229712, 229730, 230076, 230476, 231978, 233258, 234574, 234632, 234633, 234705, 235616, 235634, 235644, 237107, 237426, 238222, 238366, 238466, 239499, 239501, 240222, 241254, 241445, 243393, 243547, 243699, 243749, 243848, 244004, 244333, 245347, 245556, 247673, 247995, 248296, 248971, 249167, 249239, 249607, 249828, 249963, 250761, 251477, 251866, 251881, 251891, 251904, 252124, 252774, 254344, 254395, 255403, 255556, 258403, 261056, 261473, 261925, 262560, 262826, 263080, 263274, 263324, 263877, 268375, 272521, 274382, 274475, 275992, 276071, 276864, 279863, 280143, 280149, 281144, 281674],

# %%
# Calculando intervalo entre fraudes
time_fraud = []
for idx in range(len(fraud_idx)):
    if fraud_idx.index(fraud_idx[idx]) == 0:
        pass
    else:
        time_fraud.append(fraud_idx[idx] - fraud_idx[idx-1])

# %%
# Verificando 
print(time_fraud, end=',')
# Out:
# [82, 4297, 1188, 221, 2, 3, 2, 2, 89, 19, 26, 57, 80, 32, 76, 2, 15, 40, 46, 50, 12, 17, 4, 68, 1325, 16, 23, 280, 2, 225, 3, 127, 63, 144, 73, 235, 22, 695, 280, 13, 1, 70, 62, 60, 111, 90, 6, 446, 367, 131, 39, 190, 38, 153, 108, 1735, 66, 27, 14, 127, 828, 38, 21, 226, 25, 30, 33, 27, 170, 15, 30, 29, 605, 365, 83, 454, 49, 41, 46, 27, 986, 6, 301, 36, 1389, 3110, 114, 3380, 560, 265, 111, 11, 1938, 413, 214, 70, 14, 44, 31, 23, 506, 2274, 5907, 902, 440, 870, 174, 374, 64, 2, 464, 55, 21, 41, 19, 26, 39, 22, 4, 41, 15, 13, 15, 72, 31, 49, 9, 13, 103, 99, 44, 224, 196, 57, 92, 228, 90, 132, 47, 286, 647, 529, 1177, 9, 80, 804, 292, 2117, 326, 1929, 55, 63, 1007, 203, 1607, 1302, 545, 222, 145, 807, 339, 778, 2248, 1634, 213, 695, 82, 49, 3607, 253, 202, 111, 865, 482, 161, 448, 2168, 1027, 73, 639, 11, 287, 717, 1044, 54, 320, 170, 249, 39, 295, 1843, 11, 299, 39, 9, 877, 426, 423, 791, 653, 244, 120, 1126, 1612, 1199, 904, 49, 569, 21, 293, 2481, 1106, 647, 62, 302, 430, 1316, 63, 744, 448, 205, 2512, 1117, 886, 932, 1, 1, 1, 1, 1, 336, 2396, 1501, 319, 69, 570, 621, 450, 2982, 1150, 1431, 1868, 265, 1904, 1406, 67, 724, 332, 1642, 662, 60, 37, 32, 31, 735, 51, 28, 61, 1166, 3137, 2793, 4446, 1987, 3081, 471, 1, 1, 1, 1145, 152, 631, 145, 1, 1, 1, 392, 3, 373, 4, 646, 1046, 990, 758, 57, 1540, 212, 165, 55, 10, 13, 269, 5, 727, 43, 3, 7, 6, 1, 1, 1, 2, 1, 1, 1, 1, 8, 1, 1, 1, 4, 3, 5, 5, 18, 210, 81, 1, 1, 1, 2, 92, 93, 266, 57, 211, 77, 212, 204, 72, 1528, 12, 50, 349, 52, 85, 83, 133, 46, 35, 2, 6, 8, 9, 1, 3, 21, 1, 1, 240, 2028, 2, 595, 283, 3, 47, 5231, 437, 3598, 121, 5482, 3262, 1146, 1013, 3758, 1026, 114, 1273, 5208, 114, 177, 490, 706, 193, 92, 185, 146, 692, 147, 55, 103, 2696, 2203, 1282, 1028, 1202, 503, 1723, 4, 372, 364, 15, 424, 4148, 3865, 128, 448, 24, 1546, 113, 357, 821, 31, 2458, 583, 867, 833, 293, 23, 1092, 286, 947, 206, 6, 40, 3196, 63, 2835, 18, 346, 400, 1502, 1280, 1316, 58, 1, 72, 911, 18, 10, 1463, 319, 796, 144, 100, 1033, 2, 721, 1032, 191, 1948, 154, 152, 50, 99, 156, 329, 1014, 209, 2117, 322, 301, 675, 196, 72, 368, 221, 135, 798, 716, 389, 15, 10, 13, 220, 650, 1570, 51, 1008, 153, 2847, 2653, 417, 452, 635, 266, 254, 194, 50, 553, 4498, 4146, 1861, 93, 1517, 79, 793, 2999, 280, 6, 995, 530],

# %% [markdown]
# Pelos números obtidos, é possível identificar transações fraudulentas que ocorreram em um curto espaço de tempo, como por exemplo, de 2 ou até mesmo 1 segundo de diferença.

# %% [markdown]
# **Ideia:**
#
# Isto pode se tornar uma feature para um outro tipo de problema relacionado a fraude: seria possível prever a maior probabilidade de intervalo de tempo onde uma transação fraudulenta pode ocorrer?

# %%
# Média
time_fraud_series = pd.Series(time_fraud)
time_fraud_series.describe()
# Out:
# count     491.000000
# mean      572.572301
# std       940.142245
# min         1.000000
# 25%        34.000000
# 50%       174.000000
# 75%       711.000000
# max      5907.000000
# dtype: float64

# %% [markdown]
# Em média, transações fraudulentas ocorrem a cada 572,57 segundos. Entretanto, a confiança desta afirmação é lesada pelo alto desvio padrão contido nessa sequência de tempo a cada transação fraudulenta.

# %%
# Distribuição
fig, ax = plt.subplots()
ax = sns.distplot(time_fraud_series)
ax.set_title('Tempo por Transação Fraudulenta', size=14)
ax.set_xlabel('Tempo (s)')
plt.show()

# %%
# Violin plot
fig, ax = plt.subplots()
ax = sns.violinplot(time_fraud_series)
ax.set_title('Tempo por Transação Fraudulenta', size=14)
ax.set_xlabel('Tempo (s)')
plt.show()

# %%
# Qual a moda?
time_fraud_series.mode()[0]
# Out:
# 1

# %%
# Comunicando
print(f'Intervalo mais comum entre transações fraudulentas: \n\
{time_fraud_series.mode()[0]} segundo(s)')
# Out:
# Intervalo mais comum entre transações fraudulentas:
# 1 segundo(s)

# %%
# Procurando mais insights
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# Será que, de alguma forma, transações fraudulentas são realizadas no mesmo segundo que transações normais? Hackers mal intencionados poderiam ter conhecimento sobre transações e, para dificultar a identificação das fraudes, estas seriam realizadas no mesmo instante que outras transações.

# %%
# Calculando intervalo entre fraudes
time_transactions_idx = list(df.index)
equal_time = []
for idx in range(len(df['Time'])):
    if idx == 0:
        pass
    elif df['Time'][idx] == df['Time'][idx-1]:
        equal_time.append(idx)

# %%
# Verificando
print(equal_time, end=',')
# Out:
# [1, 3, 5, 8, 11, 12, 15, 16, 23, 25, 27, 28, 29, 33, 34, 35, 37, 39, 41, 43, 45, 46, 47, 49, 50, 52, 53, 57, 60, 61, 62, 64, 66, 67, 68, 70, 71, 74, 76, 77, 79, 82, 86, 88, 90, 92, 95, 96, 98, 100, 101, 103, 104, 105, 109, 110, 111, 113, 114, 115, 118, 120, 121, 123, 124, 125, 128, 131, 133, 134, 136, 137, 139, 143, 145, 147, 148, 150, 152, 153, 154, 157, 159, 162, 163, 164, 166, 170, 172, 175, 178, 181, 183, 186, 188, 189, 191, 192, 195, 197, 200, 203, 204, 210, 211, 212, 213, 216, 220, 221, 222, 223, 225, 229, 231, 233, 235, 236, 238, 240, 243, 244, 246, 247, 251, 253, 256, 258, 260, 262, 267, 268, 269, 270, 274, 275, 277, 279, 280, 282, 284, 285, 288, 289, 291, 292, 293, 294, 297, 302, 303, 305, 307, 309, 310, 311, 313, 315, 319, 323, 325, 329, 330, 331, 335, 336, 342, 343, 346, 350, 351, 352, 354, 355, 359, 360, 361, 363, 364, 366, 369, 372, 375, 376, 381, 384, 385, 386, 388, 390, 391, 392, 393, 397, 398, 401, 402, 403, 405, 408, 410, 411, 412, 414, 417, 419, 423, 426, 428, 429, 431, 433, 434, 436, 438, 440, 443, 444, 446, 452, 456, 458, 461, 463, 465, 470, 471, 476, 478, 480, 481, 483, 485, 486, 489, 495, 497, 500, 502, 503, 506, 509, 510, 515, 518, 521, 524, 526, 531, 535, 536, 537, 541, 542, 546, 548, 549, 551, 553, 554, 556, 559, 560, 562, 563, 566, 569, 571, 572, 573, 574, 576, 577, 579, 581, 585, 587, 589, 591, 595, 604, 607, 609, 610, 611, 614, 615, 617, 622, 623, 624, 628, 629, 632, 634, 636, 638, 639, 640, 642, 643, 647, 649, 650, 656, 657, 661, 662, 666, 670, 671, 672, 674, 676, 679, 680, 681, 683, 685, 687, 692, 694, 696, 698, 701, 702, 703, 705, 709, 711, 712, 716, 717, 723, 725, 727, 729, 730, 731, 732, 734, 737, 742, 743, 746, 747, 748, 749, 752, 755, 756, 760, 762, 764, 765, 766, 769, 772, 776, 778, 780, 787, 789, 790, 793, 794, 795, 797, 798, 801, 804, 805, 807, 808, 810, 813, 815, 816, 818, 820, 824, 825, 827, 828, 830, 832, 834, 835, 836, 839, 844, 846, 847, 848, 850, 851, 853, 855, 858, 859, 861, 862, 863, 866, 867, 868, 872, 879, 880, 881, 882, 885, 887, 890, 891, 892, 894, 895, 898, 899, 902, 904, 909, 910, 915, 916, 918, 920, 921, 923, 925, 929, 931, 932, 937, 938, 940, 942, 947, 948, 950, 953, 955, 957, 960, 963, 965, 968, 969, 971, 974, 978, 979, 981, 982, 983, 986, 993, 995, 999, 1001, 1002, 1004, 1005, 1006, 1012, 1016, 1018, 1019, 1021, 1022, 1026, 1029, 1030, 1036, 1037, 1038, 1040, 1042, 1044, 1046, 1048, 1050, 1053, 1058, 1059, 1061, 1062, 1074, 1077, 1078, 1084, 1088, 1092, 1094, 1101, 1108, 1109, 1111, 1113, 1117, 1120, 1121, 1122, 1123, 1126, 1129, 1130, 1132, 1135, 1136, 1137, 1141, 1142, 1145, 1149, 1151, 1154, 1156, 1160, 1162, 1163, 1165, 1166, 1168, 1170, 1171, 1176, 1178, 1179, 1180, 1181, 1183, 1185, 1187, 1189, 1190, 1192, 1194, 1198, 1199, 1204, 1207, 1208, 1211, 1212, 1214, 1215, 1217, 1218, 1220, 1222, 1223, 1225, 1227, 1229, 1230, 1235, 1238, 1240, 1242, 1243, 1247, 1248, 1251, 1252, 1255, 1257, 1259, 1260, 1261, 1262, 1264, 1265, 1267, 1269, 1270, 1271, 1278, 1279, 1282, 1286, 1289, 1291, 1293, 1303, 1304, 1308, 1312, 1313, 1315, 1316, 1318, 1319, 1322, 1323, 1325, 1328, 1329, 1331, 1332, 1333, 1337, 1338, 1340, 1341, 1342, 1348, 1349, 1350, 1352, 1354, 1356, 1358, 1359, 1362, 1365, 1371, 1373, 1375, 1378, 1379, 1382, 1383, 1384, 1385, 1388, 1389, 1391, 1393, 1394, 1398, 1399, 1401, 1402, 1404, 1411, 1413, 1415, 1416, 1418, 1420, 1421, 1426, 1429, 1434, 1438, 1439, 1441, 1442, 1445, 1446, 1449, 1450, 1454, 1456, 1458, 1464, 1467, 1474, 1476, 1477, 1482, 1483, 1484, 1486, 1488, 1489, 1490, 1491, 1493, 1496, 1498, 1500, 1505, 1507, 1512, 1519, 1522, 1524, 1525, 1530, 1532, 1533, 1535, 1542, 1545, 1549, 1551, 1553, 1555, 1557, 1558, 1560, 1561, 1564, 1566, 1567, 1568, 1570, 1572, 1574, 1576, 1577, 1579, 1581, 1582, 1586, 1589, 1590, 1593, 1599, 1601, 1602, 1604, 1608, 1610, 1611, 1612, 1613, 1615, 1618, 1619, 1621, 1623, 1625, 1626, 1628, 1629, 1633, 1635, 1637, 1638, 1639, 1640, 1643, 1646, 1647, 1648, 1652, 1653, 1654, 1657, 1661, 1669, 1672, 1673, 1675, 1679, 1681, 1684, 1685,  ...

# %% [markdown]
# O laço for demorou a ser executado. Estudar nova implementação com `list comprehension`.

# %% [markdown]
# De acordo com o resultado obtido, vamos verificar alguns exemplos de transações ocorridas no mesmo tempo para que possamos validar a implementação acima. Vamos visualizar os exemplos de índices 1, 3, 5, 8, 11 e 12, 15 e 16 e 23, com os índices anteriores.

# %%
# Visualizando transações que ocorreram ao mesmo tempo
idx_equal_test = [1, 3, 5, 8, 11, 12, 15, 16, 23]
idx_equal_prev = [x-1 for x in idx_equal_test]
idx_equal = np.unique(np.r_[idx_equal_prev + idx_equal_test])

df.iloc[idx_equal, np.r_[(0, -2, -1)]]
# Out:
#     Time  Amount  Class
# 0    0.0  149.62      0
# 1    0.0    2.69      0
# 2    1.0  378.66      0
# 3    1.0  123.50      0
# 4    2.0   69.99      0
# 5    2.0    3.67      0
# 7    7.0   40.80      0
# 8    7.0   93.20      0
# 10  10.0    7.80      0
# 11  10.0    9.99      0
# 12  10.0  121.50      0
# 14  12.0   58.80      0
# 15  12.0   15.99      0
# 16  12.0   12.99      0
# 22  18.0    2.28      0
# 23  18.0   22.75      0

# %% [markdown]
# A implementação funcionou! Agora temos, através do objeto `equal_time` todas as transações ocorridas ao mesmo tempo. Vamos verificar qual a porcentagem de fraude delas.

# %%
# Visualizando transações que ocorreram ao mesmo tempo
equal_time_prev = [x-1 for x in equal_time]
idx_equal = np.unique(np.r_[equal_time_prev + equal_time])

equal_time_transactions = df.iloc[idx_equal, :]
equal_time_transactions.head(6)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
# 5  0.260314 -0.568671  ...   -0.208254 -0.559825 -0.026398 -0.371427
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
# 5 -0.232794  0.105915  0.253844  0.081080    3.67      0
#
# [6 rows x 31 columns]

# %%
# Verificando quantidade
equal_time_transactions.shape[0]
# Out:
# 239644

# %%
# Comparando com o original
df.shape
# Out:
# (284807, 31)

# %% [markdown]
# A conclusão é que muitas transações foram realizadas ao mesmo tempo. Se analisarmos somente da segunda transação ao mesmo tempo pra frente, talvez possamos tirar insights mais relevantes.

# %%
# Verificando
equal_time_second_transactions = df.iloc[equal_time, :]
equal_time_second_transactions.shape[0]
# Out:
# 160215

# %%
# Dentro dessas, quantas são fraudes?
equal_time_second_transactions.query('Class==1').shape[0]
# Out:
# 248

# %% [markdown]
# Nada que nos permita extrair relevantes informações.

# %%
fig, ax = plt.subplots()
ax = sns.scatterplot(x='Time', y='Amount', data=df, alpha=.3, label='Normal')
ax = sns.scatterplot(x='Time', y='Amount', data=fraud_transactions, label='Fraude')
plt.legend()
plt.show()

# %% [markdown]
# ### Valores Iguais

# %% [markdown]
# Transações com valores repetidos podem estar relacionadas com fraude? Com que frequência ocorrem?

# %%
# Ordenando dataframe por valor transacional
ordered_value = df.sort_values('Amount')
ordered_value.head(10)
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 15816    27255.0  1.248804  0.047208  0.423388 -0.139515 -0.592217 -0.980654
# 77470    57062.0 -1.188664 -0.612034  2.422204 -0.812786  0.318493 -0.671637
# 190885  129019.0  1.868263  0.273764 -0.288023  3.835852  0.268329  0.817380
# 87335    61640.0 -0.848470  1.426562  2.137094  2.852036 -0.366945  1.158146
# 174481  121931.0 -1.184195  0.804518  2.240498  2.853175  1.038068  0.171728
# 261840  160203.0  2.037530 -0.068534 -1.566791  0.125108  0.301918 -0.714361
# 60681    49446.0  1.051131  0.078365  1.371753  2.662810 -0.347892  1.390227
# 115131   73758.0 -0.956441  1.002075  0.870574 -1.475914  0.029941 -0.326977
# 190894  129024.0  1.895858  0.300037 -0.177958  4.044251 -0.037868  0.200553
# 115136   73760.0 -0.907995  0.758230  1.819020 -0.545179 -0.795851 -0.063335
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 15816  -0.042416 -0.123044 -0.088962  ...   -0.166215 -0.501598  0.124995
# 77470  -0.432053  0.068237  0.684183  ...    0.002347  0.164823 -0.096075
# 190885 -0.287993  0.203258 -0.504927  ...    0.115927  0.610472  0.024259
# 87335  -0.416142  0.812490 -0.688381  ...   -0.210710 -0.369433 -0.271748
# 174481  0.457665  0.290123 -1.100519  ...    0.110209  0.254591 -0.475647
# 261840  0.170216 -0.085433  0.395596  ...   -0.102592 -0.344140  0.281242
# 60681  -0.742831  0.466555  0.100451  ...    0.087428  0.652637 -0.161363
# 115131  0.266672  0.654644 -0.463467  ...   -0.091851 -0.389564 -0.016400
# 190894 -0.202884  0.041879 -0.178301  ...    0.073807  0.488633  0.078707
# 115136 -0.258224  0.642900  0.517573  ...    0.183969  0.939407 -0.090921
#
#              V24       V25       V26       V27       V28  Amount  Class
# 15816   0.594070  0.119626  0.816501 -0.089465 -0.004055     0.0      0
# 77470   0.393014 -0.608295  0.745069 -0.230070 -0.018679     0.0      0
# 190885 -0.454322  0.117948  0.144547 -0.002638 -0.061637     0.0      0
# 87335  -0.571453  0.232587  0.273226  0.248532  0.088226     0.0      0
# 174481 -0.046345  0.888929  0.225662 -0.007746  0.057191     0.0      0
# 261840  0.634925 -0.084306 -0.536669 -0.044266 -0.062104     0.0      0
# 60681  -0.230979  0.584717  0.242936  0.066086  0.011721     0.0      0
# 115131 -0.296194 -0.389571  0.693608  0.128017  0.092436     0.0      0
# 190894 -0.028500  0.098306  0.137917 -0.005373 -0.048734     0.0      0
# 115136  0.541961 -0.398305  1.008075  0.244808  0.148367     0.0      0
#
# [10 rows x 31 columns]

# %%
# Indexando dataframe apenas com amostras de valores duplicados
bool_mask = ordered_value['Amount'].duplicated(keep=False)
duplicated_amount = ordered_value[bool_mask]
duplicated_amount.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 15816    27255.0  1.248804  0.047208  0.423388 -0.139515 -0.592217 -0.980654
# 77470    57062.0 -1.188664 -0.612034  2.422204 -0.812786  0.318493 -0.671637
# 190885  129019.0  1.868263  0.273764 -0.288023  3.835852  0.268329  0.817380
# 87335    61640.0 -0.848470  1.426562  2.137094  2.852036 -0.366945  1.158146
# 174481  121931.0 -1.184195  0.804518  2.240498  2.853175  1.038068  0.171728
#
#               V7        V8        V9  ...         V21       V22       V23  \
# 15816  -0.042416 -0.123044 -0.088962  ...   -0.166215 -0.501598  0.124995
# 77470  -0.432053  0.068237  0.684183  ...    0.002347  0.164823 -0.096075
# 190885 -0.287993  0.203258 -0.504927  ...    0.115927  0.610472  0.024259
# 87335  -0.416142  0.812490 -0.688381  ...   -0.210710 -0.369433 -0.271748
# 174481  0.457665  0.290123 -1.100519  ...    0.110209  0.254591 -0.475647
#
#              V24       V25       V26       V27       V28  Amount  Class
# 15816   0.594070  0.119626  0.816501 -0.089465 -0.004055     0.0      0
# 77470   0.393014 -0.608295  0.745069 -0.230070 -0.018679     0.0      0
# 190885 -0.454322  0.117948  0.144547 -0.002638 -0.061637     0.0      0
# 87335  -0.571453  0.232587  0.273226  0.248532  0.088226     0.0      0
# 174481 -0.046345  0.888929  0.225662 -0.007746  0.057191     0.0      0
#
# [5 rows x 31 columns]

# %%
# Quantas amostras com valores duplicados?
duplicated_amount.shape[0]
# Out:
# 268843

# %%
# Quantas são fraudes?
duplicated_amount.query('Class==1').shape[0]
# Out:
# 431

# %% [markdown]
# Também não é possivel tirar insights significantes dessa análise, dado que transações com valores duplicados não são tão incomuns, especialmente quando estamos falando de baixos valores.

# %% [markdown]
# ### Valores Acima da Média

# %%
# Retirando transações sem valor

# Analisando valores que superam a média
mean_amount = df['Amount'].mean()
high_amount = df.query('Amount > @mean_amount')
high_amount.head()
# Out:
#     Time        V1        V2        V3        V4        V5        V6  \
# 0    0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 2    1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3    1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 8    7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818
# 12  10.0  1.249999 -1.221637  0.383930 -1.234899 -1.485419 -0.753230
#
#           V7        V8        V9  ...         V21       V22       V23  \
# 0   0.239599  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474
# 2   0.791461  0.247676 -1.514654  ...    0.247998  0.771679  0.909412
# 3   0.237609  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321
# 8   0.370145  0.851084 -0.392048  ...   -0.073425 -0.268092 -0.204233
# 12 -0.689405 -0.227487 -2.094011  ...   -0.231809 -0.483285  0.084668
#
#          V24       V25       V26       V27       V28  Amount  Class
# 0   0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 2  -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 8   1.011592  0.373205 -0.384157  0.011747  0.142404   93.20      0
# 12  0.392831  0.161135 -0.354990  0.026416  0.042422  121.50      0
#
# [5 rows x 31 columns]

# %%
# Qual a média?
mean_amount
# Out:
# 88.34961925087359

# %%
# Quantas transações acima da média?
len(high_amount)
# Out:
# 64407

# %%
# Quantas delas são fraudes?
high_amount.query('Class==1').shape[0] / len(high_amount)
# Out:
# 0.0025463070784231528

# %% [markdown]
# A proporção do dataset original se mantém.

# %% [markdown]
# **Conclusões:**
# * Não foi possível vincular nenhuma das suposições mencionadas no início dessa sessão com transações fraudulentas. O único destaque de toda essa investigação é a conclusão de que, no geral, fraudes possuem um valor médio maior do que transações normais. Mesmo assim, essa conclusão encontram-se, de certa forma, enviesada, dado que a porcentagem de fraudes presentes no dataset representa apenas 0.17% do total, tornando esta afirmação pouco representativa dentro do contexto deste problema.

# %% [markdown]
# ### Normalizando Dados

# %% [markdown]
# Vamos aplicar o procedimento de normalização dos dados e, como nenhum insight pôde ser retirado da coluna `Time`, visto que seu significado não deve influenciar no resultado de modelos treinados, vamos elimina-la do dataset.

# %%
# Normalizando dados
from sklearn.preprocessing import StandardScaler

# Normalizando e dropando coluna Time
df['Amount'] = StandardScaler().fit_transform(df['Amount'].values.reshape(-1, 1))
df.drop('Time', axis=1, inplace=True)

# Verificando
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  0.244964      0
# 1  0.167170  0.125895 -0.008983  0.014724 -0.342475      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  1.160686      0
# 3  0.647376 -0.221929  0.062723  0.061458  0.140534      0
# 4 -0.206010  0.502292  0.219422  0.215153 -0.073403      0
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Separando os Dados

# %% [markdown]
# Antes de mais nada, vamos aplicar a separação dos dados para que possamos avaliar os modelos treinados de forma mais assertiva futuramente. Tendo em mente que este é um problema altamente desbalanceado, sabemos que será necessário algum procedimento de balanceamento, como `undersampling` ou `oversampling` para avaliação das ações tomadas. De toda forma, separar os dados originais é um processo válido que auxiliará na avaliação do modelo.

# %%
# Importando biblioteca
from sklearn.model_selection import train_test_split

# Indexando dados
X = df.iloc[:, :-1]
y = df['Class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# Verificando
print(f'Dimensões de X_train: {X_train.shape}')
print(f'Dimensões de y_train: {y_train.shape}')
print(f'Dimensões de X_test: {X_test.shape}')
print(f'Dimensões de y_test: {y_test.shape}')
# Out:
# Dimensões de X_train: (227845, 29)
# Dimensões de y_train: (227845,)
# Dimensões de X_test: (56962, 29)
# Dimensões de y_test: (56962,)

# %%
# Verificando balanceamento de classes treino
positive_class_train = sum(y_train == 1)
balance_class_train = positive_class_train / len(y_train)
print(f'Porcentagem de fraudes nos dados de treino: {100*balance_class_train:.4f}%')

# Verificando balanceamento de classes teste
positive_class_test = sum(y_test == 1)
balance_class_test = positive_class_test / len(y_test)
print(f'Porcentagem de fraudes nos dados de test: {100*balance_class_test:.4f}%')
# Out:
# Porcentagem de fraudes nos dados de treino: 0.1712%
# Porcentagem de fraudes nos dados de test: 0.1791%

# %% [markdown]
# A separação ocorreu de forma balanceada, entretando as classes em si não estão balanceadas. Temos apenas 0.17% de fraudes nos dados de treino. Isto significa que 99.83% das amostras referem-se a transações normais.
#
# **Se criarmos um modelo sem inteligência que considera todas as transações como normais, teríamos 99,83% de acurácia!** Obviamente ao preço de classificar erroneamente todas as transações fraudulentas.
#
# Por esse motivo não podemos simplesmente considerar a `acurácia` como medida de performance do nosso modelo, mas também métricas como `confusion matrix`, `precision`, `recall`, `f1_score`, `ROC curve` e `AUC score`. Para termos sucesso em nossa avaliação, precisamos aplicar um procedimento de `balanceamento` nos dados. Em um primeiro momento, vamos aplicar o procedimenteo de `under-sampling` que, por sua vez, refere-se a equalização entre as classes positiva e negativa a partir da eliminação, de forma probabilística, de exemplos da classe negativa.

# %% [markdown]
# ## Under-Sampling

# %% [markdown]
# A técnica de under-sampling simplesmente visa balancear nossos dados e promover um valor igualitário (50-50) entre as classes positiva e negativa. Alguns pontos a serem considerados:
#
# * Número de amostras da **classe positiva**;
# * Maneira correta de aplicar o **shuffle** nos dados;
# * Considerar **perda de informação** ao deletar instâncias do dataset original.

# %%
# Já temos os dataframes indexados da análise exploratória
total_fraud = len(fraud_transactions)
total_normal = len(normal_transactions)
print(f'Quantidade de fraudes: {total_fraud}')
print(f'Transações normais: {total_normal}')
# Out:
# Quantidade de fraudes: 492
# Transações normais: 284315

# %%
# Embaralhando e balanceando dataset
shuffle_index = np.random.choice(normal_transactions.index, total_fraud, replace=False)
print(f'Quantidade de índices embaralhados: {len(shuffle_index)}')

# Unindo índices e criando novo dataframe
undersampled_index = np.concatenate([shuffle_index, fraud_transactions.index])
df_undersampled = df.iloc[undersampled_index, :]
print(f'Total de linhas do novo dataframe balanceado: {len(undersampled_index)}')

# Verificando cabeçalho
df_undersampled.head()
# Out:
# Quantidade de índices embaralhados: 492
# Total de linhas do novo dataframe balanceado: 984
#               V1        V2        V3        V4        V5        V6        V7  \
# 141427  1.299502  0.198593  0.053710  0.226985  0.183877  0.009904 -0.036899
# 166260  2.020079 -1.160015 -0.381219 -0.763190 -1.316617 -0.735895 -0.971131
# 62724  -1.381353  0.416942  1.282141  1.218570  0.350295 -0.471489 -0.430381
# 99931   1.351204 -0.738216 -0.341640 -2.280200 -0.420878 -0.112127 -0.529315
# 107780  1.219840 -1.216819  1.500564  0.008895 -2.063361  0.170025 -1.418221
#
#               V8        V9       V10  ...         V21       V22       V23  \
# 141427 -0.007927 -0.198967  0.092300  ...   -0.277472 -0.812188 -0.025482
# 166260 -0.163439  0.035860  0.714427  ...    0.451507  1.237282  0.075322
# 62724   0.650595 -0.859901  0.013487  ...    0.137515  0.074268 -0.101151
# 99931   0.136516  2.617435 -1.586728  ...   -0.080578  0.000060 -0.250707
# 107780  0.253406  0.851582  0.260285  ...   -0.595305 -0.878781  0.082643
#
#              V24       V25       V26       V27       V28    Amount  Class
# 141427 -0.831438  0.357378  0.148061 -0.031665 -0.002049 -0.345313      0
# 166260  0.044001 -0.223377 -0.072192  0.010241 -0.031934 -0.033382      0
# 62724   0.000011 -0.251732 -0.384402  0.306575 -0.003686 -0.338836      0
# 99931  -1.332520  0.773713 -0.612328  0.083042  0.003915 -0.313249      0
# 107780  0.426885  0.094261  1.031082  0.009885  0.023069 -0.206700      0
#
# [5 rows x 30 columns]

# %%
# Verificando balanceamento entre classes
df_undersampled['Class'].value_counts()
# Out:
# 1    492
# 0    492
# Name: Class, dtype: int64

# %%
# Visualizando graficamente
custom_colors = ["#3498db", "#C8391A"]
fig, ax = plt.subplots()
ax = sns.countplot(x='Class', data=df_undersampled, palette=custom_colors)
format_spines(ax, right_border=False)
ax.set_title('Quantidade por Tipo de Transação', size=14)

ncount = len(df_undersampled)
for p in ax.patches:
    x=p.get_bbox().get_points()[:,0]
    y=p.get_bbox().get_points()[1,1]
    ax.annotate('{:.1f}%'.format(100.*y/ncount), (x.mean(), y), 
            ha='center', va='bottom') # set the alignment of the text
plt.tight_layout()
plt.subplots_adjust(top=1.1)
ax.set_xticklabels(['Normal', 'Fraude'])
plt.show()

# %% [markdown]
# Agora que temos um conjunto balanceado, vamos aplicar um pipeline de treinamento com alguns classificadores para eleger um algoritmo específico para se trabalhar e aprimorar. Para isso, vamos:
#
# * Separar os dados em **treino** e **teste**;
# * Eleger *5 ou 6* classificadores;
# * Avaliar `acurácia`, `precision`, `recall`, `f1_score`, `matriz de confusão`, `ROC curve`
# * Avaliar métricas nos dados de **treino undersampled**;
# * Avaliar métricas nos dados de **teste undersamples**;
# * Avaliar métricas nos dados de **teste original**.

# %% [markdown]
# ### Separando os Dados (Under-Sampling)

# %%
# Separando os dados
X_under = df_undersampled.iloc[:, :-1]
y_under = df_undersampled['Class']
X_train_under, X_test_under, y_train_under, y_test_under = train_test_split(X_under, y_under,
                                                                           test_size=.2)

# Verificando
print(f'Dimensões de X_train_under: {X_train_under.shape}')
print(f'Dimensões de y_train_under: {y_train_under.shape}')
print(f'Dimensões de X_test_under: {X_test_under.shape}')
print(f'Dimensões de y_test_under: {y_test_under.shape}')
# Out:
# Dimensões de X_train_under: (787, 29)
# Dimensões de y_train_under: (787,)
# Dimensões de X_test_under: (197, 29)
# Dimensões de y_test_under: (197,)

# %%
# Verificando balanceamento de classes treino
positive_under_train = sum(y_train_under == 1)
balance_under_train = positive_under_train / len(y_train_under)
print(f'Porcentagem de fraudes nos dados de treino: {100*balance_under_train:.4f}%')

# Verificando balanceamento de classes teste
positive_under_test = sum(y_test_under == 1)
balance_under_test = positive_under_test / len(y_test_under)
print(f'Porcentagem de fraudes nos dados de test: {100*balance_under_test:.4f}%')
# Out:
# Porcentagem de fraudes nos dados de treino: 49.5553%
# Porcentagem de fraudes nos dados de test: 51.7766%

# %% [markdown]
# Dataset balanceado em níveis razoáveis. Vamos seguir com os treinamentos

# %% [markdown]
# ### Avaliando Modelos Candidatos

# %%
# Importando módulos
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier

# %%
# Create a confusion matrix
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    """if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    else:
        print('Confusion matrix, without normalization')

    print(cm)"""

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=14)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
# Dicionário de classificadores
classifiers = {
    'log_reg': LogisticRegression(),
    'tree_clf': DecisionTreeClassifier(),
    'forest_clf': RandomForestClassifier(),
    'svm_clf': SVC(),
    'knn_clf': KNeighborsClassifier(),
    'mlp_clf': MLPClassifier()
}

# %%
# Importando bibliotecas a serem utilizadas
from sklearn.model_selection import cross_val_predict, cross_val_score
from sklearn.metrics import accuracy_score, precision_score, recall_score, \
                            precision_recall_curve, f1_score, confusion_matrix, roc_curve, \
                            roc_auc_score
import time
import warnings
warnings.filterwarnings('ignore')

# %%
# Treinando classificadores (acurácia)
for key, model in classifiers.items():
    t0 = time.time()
    
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    train_cv_score = cross_val_score(model, X_train_under, y_train_under, cv=5).mean()
    
    # Retornando parâmetros para comunicação dos resultados
    t1 = time.time()
    delta_time = t1-t0
    model_name = model.__class__.__name__
    
    # Comunicando
    print(f'Acurácia do modelo {model_name}: {100*train_cv_score:.4f}% em \
{delta_time:.3f}s')
# Out:
# Acurácia do modelo LogisticRegression: 93.6475% em 0.058s
# Acurácia do modelo DecisionTreeClassifier: 90.0895% em 0.128s
# Acurácia do modelo RandomForestClassifier: 93.8999% em 0.295s
# Acurácia do modelo SVC: 93.7765% em 0.314s
# Acurácia do modelo KNeighborsClassifier: 94.5360% em 0.065s
# Acurácia do modelo MLPClassifier: 93.9023% em 5.998s

# %% [markdown]
# Interessante avaliar a acurácia e o tempo de cálculo de cada modelo. Entretanto, dentro do contexto deste problema de detecção de fraude, estamos interessado no `recall` do modelo, isto é, não é desejável que transações fraudulentas passem batidas. Portanto, aumentar o recall significa identificar o maior número de transações fraudulentas possíveis, mesmo que isto se dê ao custo de um aumento significativos de Falsos Positivos (transações normais dadas como fraude).
#
# O impacto de identificar uma transação normal como fraude é muito menor do que o impacto em classificar uma fraude como transação normal.

# %%
# Treinando classificadores (recall)
for key, model in classifiers.items():
    t0 = time.time()
    
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    train_cv_score = cross_val_score(model, X_train_under, y_train_under, cv=5,
                                    scoring='recall').mean()
    
    # Retornando parâmetros para comunicação dos resultados
    t1 = time.time()
    delta_time = t1-t0
    model_name = model.__class__.__name__
    
    # Comunicando
    print(f'Recall do modelo {model_name}: {100*train_cv_score:.4f}% em \
{delta_time:.3f}s')
# Out:
# Recall do modelo LogisticRegression: 90.5128% em 0.091s
# Recall do modelo DecisionTreeClassifier: 91.0256% em 0.125s
# Recall do modelo RandomForestClassifier: 90.2564% em 0.227s
# Recall do modelo SVC: 91.2821% em 0.194s
# Recall do modelo KNeighborsClassifier: 90.5128% em 0.069s
# Recall do modelo MLPClassifier: 91.2821% em 6.199s

# %% [markdown]
# #### Treino Under Sampling

# %% [markdown]
# Vamos avaliar os modelos candidatos a partir dos dados de treino undersampled.

# %%
# Vamos criar um dataframe para analisar os scores de todos os modelos
def create_dataset():
    """
    Função para criação (primeira vez) de um dataset vazio para armazenar acurácias
    """
    attributes = ['acc', 'prec', 'rec', 'f1', 'total_time']
    model_performance = pd.DataFrame({})
    for col in attributes:
        model_performance[col] = []
    return model_performance

# %%
# Criando dataframe
model_train_performance_under = create_dataset()
model_train_performance_under
# Out:
# Empty DataFrame
# Columns: [acc, prec, rec, f1, total_time]
# Index: []

# %%
# Treinando classificadores (acc, precision, recall e f1_score)
for key, model in classifiers.items():
    t0 = time.time()
    
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    train_cv_acc = cross_val_score(model, X_train_under, y_train_under, cv=5,
                                    scoring='accuracy').mean()
    train_cv_precision = cross_val_score(model, X_train_under, y_train_under, cv=5,
                                    scoring='precision').mean()
    train_cv_recall = cross_val_score(model, X_train_under, y_train_under, cv=5,
                                    scoring='recall').mean()
    train_cv_f1 = cross_val_score(model, X_train_under, y_train_under, cv=5,
                                    scoring='f1').mean()
    
    # Retornando parâmetros para comunicação dos resultados
    t1 = time.time()
    delta_time = t1-t0
    model_name = model.__class__.__name__
    
    # Salvando em dataframe
    performances = {}
    performances['acc'] = round(train_cv_acc, 4)
    performances['prec'] = round(train_cv_precision, 4)
    performances['rec'] = round(train_cv_recall, 4)
    performances['f1'] = round(train_cv_f1, 4)
    performances['total_time'] = round(delta_time, 3)
    
    model_train_performance_under = model_train_performance_under.append\
(performances, ignore_index=True)

# %%
# Verificando resultados
model_train_performance_under.index = classifiers.keys()
model_train_performance_under
# Out:
#                acc    prec     rec      f1  total_time
# log_reg     0.9365  0.9646  0.9051  0.9338       0.143
# tree_clf    0.9098  0.9082  0.9051  0.9047       0.250
# forest_clf  0.9314  0.9731  0.9000  0.9331       0.385
# svm_clf     0.9378  0.9596  0.9128  0.9355       0.354
# knn_clf     0.9454  0.9835  0.9051  0.9426       0.154
# mlp_clf     0.9441  0.9623  0.9179  0.9382      10.163

# %%
# Verificando o melhor modelo em cada métrica
best_acc = model_train_performance_under[model_train_performance_under['acc'] == \
                             model_train_performance_under['acc'].max()].index[0]
best_prec = model_performance[model_train_performance_under['prec'] == \
                             model_train_performance_under['prec'].max()].index[0]
best_rec = model_performance[model_train_performance_under['rec'] == \
                             model_train_performance_under['rec'].max()].index[0]
best_f1 = model_performance[model_train_performance_under['f1'] == \
                             model_train_performance_under['f1'].max()].index[0]
best_time = model_performance[model_train_performance_under['total_time'] == \
                             model_train_performance_under['total_time'].min()].index[0]

# Comunicando
print(f'Melhor acurácia: {best_acc}')
print(f'Melhor precision: {best_prec}')
print(f'Melhor recall: {best_rec}')
print(f'Melhor f1: {best_f1}')
print(f'Menor tempo: {best_time}')
# Out:
# Melhor acurácia: knn_clf
# Melhor precision: knn_clf
# Melhor recall: mlp_clf
# Melhor f1: knn_clf
# Menor tempo: log_reg

# %%
# Visualizando de forma mais agradável
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)
model_train_performance_under.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col0 {
#             background-color:  #3aa03a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col1 {
#             background-color:  #3aa03a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col2 {
#             background-color:  #a5dba5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col3 {
#             background-color:  #359d35;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col2 {
#             background-color:  #a5dba5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col4 {
#             background-color:  #e4fee4;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col0 {
#             background-color:  #5ab25a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col1 {
#             background-color:  #1f911f;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col2 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col3 {
#             background-color:  #3aa03a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col4 {
#             background-color:  #e0fce0;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col0 {
#             background-color:  #319b31;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col1 {
#             background-color:  #49a849;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col2 {
#             background-color:  #41a441;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col3 {
#             background-color:  #2a972a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col4 {
#             background-color:  #e1fde1;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col0 {
#             background-color:  #008000;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col1 {
#             background-color:  #008000;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col2 {
#             background-color:  #a5dba5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col3 {
#             background-color:  #008000;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col0 {
#             background-color:  #088408;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col1 {
#             background-color:  #41a441;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col2 {
#             background-color:  #008000;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col3 {
#             background-color:  #1a8e1a;
#         }    #T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col4 {
#             background-color:  #008000;
#         }</style>
# <table id="T_12e35106_7c52_11e9_986d_d46a6af96bb4" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >acc</th>
#         <th class="col_heading level0 col1" >prec</th>
#         <th class="col_heading level0 col2" >rec</th>
#         <th class="col_heading level0 col3" >f1</th>
#         <th class="col_heading level0 col4" >total_time</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row0" class="row_heading level0 row0" >log_reg</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col0" class="data row0 col0" >0.9365</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col1" class="data row0 col1" >0.9646</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col2" class="data row0 col2" >0.9051</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col3" class="data row0 col3" >0.9338</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row0_col4" class="data row0 col4" >0.143</td>
#     </tr>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row1" class="row_heading level0 row1" >tree_clf</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col0" class="data row1 col0" >0.9098</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col1" class="data row1 col1" >0.9082</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col2" class="data row1 col2" >0.9051</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col3" class="data row1 col3" >0.9047</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row1_col4" class="data row1 col4" >0.25</td>
#     </tr>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row2" class="row_heading level0 row2" >forest_clf</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col0" class="data row2 col0" >0.9314</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col1" class="data row2 col1" >0.9731</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col2" class="data row2 col2" >0.9</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col3" class="data row2 col3" >0.9331</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row2_col4" class="data row2 col4" >0.385</td>
#     </tr>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row3" class="row_heading level0 row3" >svm_clf</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col0" class="data row3 col0" >0.9378</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col1" class="data row3 col1" >0.9596</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col2" class="data row3 col2" >0.9128</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col3" class="data row3 col3" >0.9355</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row3_col4" class="data row3 col4" >0.354</td>
#     </tr>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row4" class="row_heading level0 row4" >knn_clf</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col0" class="data row4 col0" >0.9454</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col1" class="data row4 col1" >0.9835</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col2" class="data row4 col2" >0.9051</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col3" class="data row4 col3" >0.9426</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row4_col4" class="data row4 col4" >0.154</td>
#     </tr>    <tr>
#         <th id="T_12e35106_7c52_11e9_986d_d46a6af96bb4level0_row5" class="row_heading level0 row5" >mlp_clf</th>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col0" class="data row5 col0" >0.9441</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col1" class="data row5 col1" >0.9623</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col2" class="data row5 col2" >0.9179</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col3" class="data row5 col3" >0.9382</td>
#         <td id="T_12e35106_7c52_11e9_986d_d46a6af96bb4row5_col4" class="data row5 col4" >10.163</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# A análise acima deixa nítido alguns pontos desta primeira análise, como a boa performance do classficador `knn` e o alto tempo demandado pelo classificador `mlp`.

# %% [markdown]
# Vamos visualizar a **Matriz de Confusão** de cada um dos modelos (considerando ainda os dados de treino).

# %%
# Plotando matriz de confusão para cada modelo (considerando dados de treino)
i = 1
plt.figure(figsize=(11, 11))
sns.set(style='white', palette='muted', color_codes=True)
labels = ['No Fraud', 'Fraud']

for key, model in classifiers.items(): 
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    model_pred = model.predict(X_train_under)
    model_cf_mx = confusion_matrix(y_train_under, model_pred)
    
    # Plotando matriz
    model_name = model.__class__.__name__
    plt.subplot(3, 3, i)
    plot_confusion_matrix(model_cf_mx, labels, title=model_name + '\nConfusion Matrix')
    i += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Aqui temos uma visão clara sobre como os modelos se comportam nos dados de treino. Indicadores nítidos de `overfitting` podem ser visualizados nos modelos `DecisionTrees` e `RandomForest` (situação característica dessas estruturas sem nenhuma limitação das árvores), além também do modelo `MLPClassifier`. Vamos repetir essa análise utilizando os dados de teste obtidos no resampling.

# %% [markdown]
# #### Teste Under Sampling

# %%
# Criando dataframe
model_test_performance_under = create_dataset()
model_test_performance_under
# Out:
# Empty DataFrame
# Columns: [acc, prec, rec, f1, total_time]
# Index: []

# %%
# Treinando classificadores (acc, precision, recall e f1_score)
for key, model in classifiers.items():
    t0 = time.time()
    
    # Treinando modelo e predizendo com dados de teste undersampled
    model.fit(X_train_under, y_train_under)
    model_pred = model.predict(X_test_under)
    
    # Avaliando scores
    test_acc_under = accuracy_score(y_test_under, model_pred)
    test_prec_under = precision_score(y_test_under, model_pred)
    test_rec_under = recall_score(y_test_under, model_pred)
    test_f1_under = f1_score(y_test_under, model_pred)
    
    # Retornando parâmetros para comunicação dos resultados
    t1 = time.time()
    delta_time = t1-t0
    model_name = model.__class__.__name__
    
    # Salvando em dataframe
    performances = {}
    performances['acc'] = round(test_acc_under, 4)
    performances['prec'] = round(test_prec_under, 4)
    performances['rec'] = round(test_rec_under, 4)
    performances['f1'] = round(test_f1_under, 4)
    performances['total_time'] = round(delta_time, 3)
    
    model_test_performance_under = model_test_performance_under.append\
(performances, ignore_index=True)

# %%
# Visualizando
model_test_performance_under.index = classifiers.keys()
cm = sns.light_palette("green", as_cmap=True)
model_test_performance_under.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col0 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col1 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col2 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col3 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col1 {
#             background-color:  #c8efc8;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col4 {
#             background-color:  #e3fee3;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col0 {
#             background-color:  #a4dba4;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col1 {
#             background-color:  #9ed89e;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col2 {
#             background-color:  #73c073;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col3 {
#             background-color:  #a3daa3;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col4 {
#             background-color:  #dcfadc;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col0 {
#             background-color:  #c5edc5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col1 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col2 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col3 {
#             background-color:  #bee9be;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col4 {
#             background-color:  #dffcdf;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col0 {
#             background-color:  #42a442;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col1 {
#             background-color:  #028102;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col2 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col3 {
#             background-color:  #46a746;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col4 {
#             background-color:  #e5ffe5;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col0 {
#             background-color:  #209220;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col1 {
#             background-color:  #289628;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col2 {
#             background-color:  #008000;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col3 {
#             background-color:  #1f911f;
#         }    #T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col4 {
#             background-color:  #008000;
#         }</style>
# <table id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >acc</th>
#         <th class="col_heading level0 col1" >prec</th>
#         <th class="col_heading level0 col2" >rec</th>
#         <th class="col_heading level0 col3" >f1</th>
#         <th class="col_heading level0 col4" >total_time</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row0" class="row_heading level0 row0" >log_reg</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col0" class="data row0 col0" >0.9645</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col1" class="data row0 col1" >0.9703</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col2" class="data row0 col2" >0.9608</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col3" class="data row0 col3" >0.9655</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row0_col4" class="data row0 col4" >0.013</td>
#     </tr>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row1" class="row_heading level0 row1" >tree_clf</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col0" class="data row1 col0" >0.9289</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col1" class="data row1 col1" >0.9231</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col2" class="data row1 col2" >0.9412</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col3" class="data row1 col3" >0.932</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row1_col4" class="data row1 col4" >0.017</td>
#     </tr>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row2" class="row_heading level0 row2" >forest_clf</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col0" class="data row2 col0" >0.9391</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col1" class="data row2 col1" >0.9327</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col2" class="data row2 col2" >0.951</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col3" class="data row2 col3" >0.9417</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row2_col4" class="data row2 col4" >0.032</td>
#     </tr>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row3" class="row_heading level0 row3" >svm_clf</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col0" class="data row3 col0" >0.934</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col1" class="data row3 col1" >0.9159</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col2" class="data row3 col2" >0.9608</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col3" class="data row3 col3" >0.9378</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row3_col4" class="data row3 col4" >0.026</td>
#     </tr>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row4" class="row_heading level0 row4" >knn_clf</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col0" class="data row4 col0" >0.9543</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col1" class="data row4 col1" >0.9697</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col2" class="data row4 col2" >0.9412</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col3" class="data row4 col3" >0.9552</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row4_col4" class="data row4 col4" >0.01</td>
#     </tr>    <tr>
#         <th id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4level0_row5" class="row_heading level0 row5" >mlp_clf</th>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col0" class="data row5 col0" >0.9594</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col1" class="data row5 col1" >0.9608</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col2" class="data row5 col2" >0.9608</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col3" class="data row5 col3" >0.9608</td>
#         <td id="T_e059759a_7c52_11e9_86fa_d46a6af96bb4row5_col4" class="data row5 col4" >0.532</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# Percebemos que o algoritmo `LogisticRegression` apresentou os melhores resultados no geral. Vejamos a matriz de confusão.

# %%
# Plotando matriz de confusão para cada modelo (considerando dados de teste)
i = 1
plt.figure(figsize=(11, 11))
sns.set(style='white', palette='muted', color_codes=True)
labels = ['No Fraud', 'Fraud']

for key, model in classifiers.items(): 
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    model_pred = model.predict(X_test_under)
    model_cf_mx = confusion_matrix(y_test_under, model_pred)
    
    # Plotando matriz
    model_name = model.__class__.__name__
    plt.subplot(3, 3, i)
    plot_confusion_matrix(model_cf_mx, labels, title=model_name + '\nConfusion Matrix')
    i += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Nosso grande desafio agora é verificar a performance de cada modelo treinado nos dados de teste originais. Vejamos.

# %% [markdown]
# #### Teste Original

# %%
# Criando dataframe
model_test_performance_original = create_dataset()
model_test_performance_original
# Out:
# Empty DataFrame
# Columns: [acc, prec, rec, f1, total_time]
# Index: []

# %%
# Treinando classificadores (acc, precision, recall e f1_score)
for key, model in classifiers.items():
    t0 = time.time()
    
    # Treinando modelo e predizendo com dados de teste undersampled
    model.fit(X_train_under, y_train_under)
    model_pred = model.predict(X_test)
    
    # Avaliando scores
    test_acc_original = accuracy_score(y_test, model_pred)
    test_prec_original = precision_score(y_test, model_pred)
    test_rec_original = recall_score(y_test, model_pred)
    test_f1_original = f1_score(y_test, model_pred)
    
    # Retornando parâmetros para comunicação dos resultados
    t1 = time.time()
    delta_time = t1-t0
    model_name = model.__class__.__name__
    
    # Salvando em dataframe
    performances = {}
    performances['acc'] = round(test_acc_original, 4)
    performances['prec'] = round(test_prec_original, 4)
    performances['rec'] = round(test_rec_original, 4)
    performances['f1'] = round(test_f1_original, 4)
    performances['total_time'] = round(delta_time, 3)
    
    model_test_performance_original = model_test_performance_original.append\
(performances, ignore_index=True)

# %%
# Visualizando
model_test_performance_original.index = classifiers.keys()
cm = sns.light_palette("green", as_cmap=True)
model_test_performance_original.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col0 {
#             background-color:  #178d17;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col1 {
#             background-color:  #3aa03a;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col2 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col3 {
#             background-color:  #399f39;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col0 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col1 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col2 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col3 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col4 {
#             background-color:  #e5ffe5;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col0 {
#             background-color:  #289628;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col1 {
#             background-color:  #4aa94a;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col2 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col3 {
#             background-color:  #48a848;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col4 {
#             background-color:  #dffcdf;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col0 {
#             background-color:  #82c882;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col1 {
#             background-color:  #b7e5b7;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col2 {
#             background-color:  #b8e6b8;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col3 {
#             background-color:  #b6e5b6;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col4 {
#             background-color:  #76c176;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col0 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col1 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col2 {
#             background-color:  #b8e6b8;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col3 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col4 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col0 {
#             background-color:  #249424;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col1 {
#             background-color:  #44a544;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col2 {
#             background-color:  #008000;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col3 {
#             background-color:  #41a441;
#         }    #T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col4 {
#             background-color:  #86ca86;
#         }</style>
# <table id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >acc</th>
#         <th class="col_heading level0 col1" >prec</th>
#         <th class="col_heading level0 col2" >rec</th>
#         <th class="col_heading level0 col3" >f1</th>
#         <th class="col_heading level0 col4" >total_time</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row0" class="row_heading level0 row0" >log_reg</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col0" class="data row0 col0" >0.961</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col1" class="data row0 col1" >0.0415</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col2" class="data row0 col2" >0.9412</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col3" class="data row0 col3" >0.0795</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row0_col4" class="data row0 col4" >0.093</td>
#     </tr>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row1" class="row_heading level0 row1" >tree_clf</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col0" class="data row1 col0" >0.9104</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col1" class="data row1 col1" >0.0194</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col2" class="data row1 col2" >0.9902</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col3" class="data row1 col3" >0.0381</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row1_col4" class="data row1 col4" >0.102</td>
#     </tr>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row2" class="row_heading level0 row2" >forest_clf</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col0" class="data row2 col0" >0.9568</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col1" class="data row2 col1" >0.0395</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col2" class="data row2 col2" >0.9902</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col3" class="data row2 col3" >0.0759</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row2_col4" class="data row2 col4" >0.15</td>
#     </tr>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row3" class="row_heading level0 row3" >svm_clf</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col0" class="data row3 col0" >0.9348</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col1" class="data row3 col1" >0.0255</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col2" class="data row3 col2" >0.951</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col3" class="data row3 col3" >0.0497</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row3_col4" class="data row3 col4" >1.032</td>
#     </tr>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row4" class="row_heading level0 row4" >knn_clf</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col0" class="data row4 col0" >0.9668</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col1" class="data row4 col1" >0.049</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col2" class="data row4 col2" >0.951</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col3" class="data row4 col3" >0.0931</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row4_col4" class="data row4 col4" >2.024</td>
#     </tr>    <tr>
#         <th id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4level0_row5" class="row_heading level0 row5" >mlp_clf</th>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col0" class="data row5 col0" >0.9578</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col1" class="data row5 col1" >0.0403</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col2" class="data row5 col2" >0.9902</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col3" class="data row5 col3" >0.0775</td>
#         <td id="T_b1ac4164_7c53_11e9_b21c_d46a6af96bb4row5_col4" class="data row5 col4" >0.893</td>
#     </tr></tbody>
# </table>

# %% [markdown]
# De cara, é possível perceber que obtivemos excelentes resultados para `recall`, porém ao preço de péssimos resultados para `precision`. Futuramente, veremos que isto está relacionado ao threshold de cada modelo, tal qual poderá ser visto na curva `Precision x Recall`.

# %%
# Plotando matriz de confusão para cada modelo (considerando dados de treino)
i = 1
plt.figure(figsize=(11, 11))
sns.set(style='white', palette='muted', color_codes=True)
labels = ['No Fraud', 'Fraud']

for key, model in classifiers.items(): 
    # Treinando modelo e avaliando score em validação cruzada
    model.fit(X_train_under, y_train_under)
    model_pred = model.predict(X_test)
    model_cf_mx = confusion_matrix(y_test, model_pred)
    
    # Plotando matriz
    model_name = model.__class__.__name__
    plt.subplot(3, 3, i)
    plot_confusion_matrix(model_cf_mx, labels, title=model_name + '\nConfusion Matrix')
    i += 1
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Os bons resultados de `recall`, ou seja, o bom índice de classificação de fraudes, deixando passar o mínimo possível, veio a um grande preço de queda de `precision`, ou seja, um considerável aumento nos Falsos Positivos, ou seja, transações normais classificadas como fraudulentas.
#
# Por exemplo, na matriz de confusão do modeo de **Regressão Logística**, é possível identificar que, de 102 fraudes disponíveis, o modelo conseguiu classificar 96 corretamente, deixando passar apenas 6. Entretanto, 2218 transações normais foram classificadas como fraude, o que não é bom.

# %% [markdown]
# #### ROC Curve

# %% [markdown]
# Vamos comparar a ROC curve de cada um dos modelos, ainda nos dados undersampled.

# %%
# Treinando classificadores (acc, precision, recall e f1_score)
plt.figure(figsize=(8, 6))

for key, model in classifiers.items():
    
    # Treinando modelo e predizendo com dados de teste undersampled
    model.fit(X_train_under, y_train_under)

    # Calculando scores e Area Under the Curve
    try:
        y_scores = cross_val_predict(model, X_test_under, y_test_under, cv=5, 
                                     method='decision_function')
    except:
        # Trata-se de uma Árvore de Decisão que não possui o método "decision_function"
        y_probas = cross_val_predict(model, X_test_under, y_test_under, cv=5, 
                                     method='predict_proba')
        y_scores_tree = y_probas[:, 1]
        y_scores = y_scores_tree
        
    # Calculando ROC Curve
    model_name = model.__class__.__name__
    fpr, tpr, thresholds = roc_curve(y_test_under, y_scores)
    auc = roc_auc_score(y_test_under, y_scores)
    plot_roc_curve(fpr, tpr, y_test_under, y_scores, auc, label=model_name)

# %% [markdown]
# #### Precision x Recall

# %% [markdown]
# Um ponto fundamental da análise de modelos desbalanceados é a troca entre Precision e Recall.

# %%
# Treinando classificadores
plt.figure(figsize=(8, 6))

for key, model in classifiers.items():
    
    # Treinando modelo e predizendo com dados de teste undersampled
    model.fit(X_train_under, y_train_under)

    # Calculando scores e Area Under the Curve
    try:
        y_scores = cross_val_predict(model, X_test_under, y_test_under, cv=5, 
                                     method='decision_function')
    except:
        # Trata-se de uma Árvore de Decisão que não possui o método "decision_function"
        y_probas = cross_val_predict(model, X_test_under, y_test_under, cv=5, 
                                     method='predict_proba')
        y_scores_tree = y_probas[:, 1]
        y_scores = y_scores_tree
    
    precisions, recalls, thresholds = precision_recall_curve(y_test_under, y_scores)
        
    # Calculando Precision x Recall curve
    model_name = model.__class__.__name__
    plot_precision_vs_recall(precisions, recalls, label=model_name)

# %% [markdown]
# ## Regressão Logística

# %% [markdown]
# Para continuar nossa análise, vamos escolher um único modelo, neste primeiro momento, para investigar as melhorias necessárias de modo a transformar nosso modelo com as melhores configurações possíveis. Por critérios de facilidade e performance, vamos analisar mais a fundo o modelo de **Regressão Logística**.

# %% [markdown]
# ### Under-Sampled
