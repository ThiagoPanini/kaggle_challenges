# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introdução" data-toc-modified-id="Introdução-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introdução</a></span></li><li><span><a href="#Funções-Úteis" data-toc-modified-id="Funções-Úteis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Funções Úteis</a></span></li><li><span><a href="#Lendo-os-Dados" data-toc-modified-id="Lendo-os-Dados-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Lendo os Dados</a></span></li><li><span><a href="#Explorando-os-Dados" data-toc-modified-id="Explorando-os-Dados-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Explorando os Dados</a></span><ul class="toc-item"><li><span><a href="#Pré-Análise" data-toc-modified-id="Pré-Análise-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Pré-Análise</a></span></li><li><span><a href="#Dados-Nulos" data-toc-modified-id="Dados-Nulos-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Dados Nulos</a></span><ul class="toc-item"><li><span><a href="#Atributos-Categóricos" data-toc-modified-id="Atributos-Categóricos-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Atributos Categóricos</a></span><ul class="toc-item"><li><span><a href="#Filtrando-Atributos" data-toc-modified-id="Filtrando-Atributos-4.2.1.1"><span class="toc-item-num">4.2.1.1&nbsp;&nbsp;</span>Filtrando Atributos</a></span></li><li><span><a href="#Preenchendo-Dados-Nulos" data-toc-modified-id="Preenchendo-Dados-Nulos-4.2.1.2"><span class="toc-item-num">4.2.1.2&nbsp;&nbsp;</span>Preenchendo Dados Nulos</a></span></li></ul></li><li><span><a href="#Atributos-Numéricos" data-toc-modified-id="Atributos-Numéricos-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Atributos Numéricos</a></span><ul class="toc-item"><li><span><a href="#Preenchendo-Dados-Nulos" data-toc-modified-id="Preenchendo-Dados-Nulos-4.2.2.1"><span class="toc-item-num">4.2.2.1&nbsp;&nbsp;</span>Preenchendo Dados Nulos</a></span></li></ul></li></ul></li><li><span><a href="#Correlações" data-toc-modified-id="Correlações-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Correlações</a></span></li></ul></li><li><span><a href="#Pipeline" data-toc-modified-id="Pipeline-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Pipeline</a></span><ul class="toc-item"><li><span><a href="#Pipeline-Categórico" data-toc-modified-id="Pipeline-Categórico-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pipeline Categórico</a></span></li><li><span><a href="#Pipeline-Numérico" data-toc-modified-id="Pipeline-Numérico-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Pipeline Numérico</a></span></li><li><span><a href="#Pipeline-Completo" data-toc-modified-id="Pipeline-Completo-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Pipeline Completo</a></span></li></ul></li><li><span><a href="#Treinando-um-Modelo" data-toc-modified-id="Treinando-um-Modelo-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Treinando um Modelo</a></span><ul class="toc-item"><li><span><a href="#Primeira-Abordagem" data-toc-modified-id="Primeira-Abordagem-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Primeira Abordagem</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Decision-Trees-Regressor" data-toc-modified-id="Decision-Trees-Regressor-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Decision Trees Regressor</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Random Forest</a></span></li><li><span><a href="#SVR-Regressor" data-toc-modified-id="SVR-Regressor-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>SVR Regressor</a></span></li><li><span><a href="#Grid-Search-CV" data-toc-modified-id="Grid-Search-CV-6.1.5"><span class="toc-item-num">6.1.5&nbsp;&nbsp;</span>Grid Search CV</a></span></li><li><span><a href="#Feature-Importance" data-toc-modified-id="Feature-Importance-6.1.6"><span class="toc-item-num">6.1.6&nbsp;&nbsp;</span>Feature Importance</a></span></li></ul></li><li><span><a href="#Segunda-Abordagem" data-toc-modified-id="Segunda-Abordagem-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Segunda Abordagem</a></span></li><li><span><a href="#Terceira-Abordagem" data-toc-modified-id="Terceira-Abordagem-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Terceira Abordagem</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression" data-toc-modified-id="Linear-Regression-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Linear Regression</a></span></li><li><span><a href="#Ridge-Regression" data-toc-modified-id="Ridge-Regression-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Ridge Regression</a></span></li><li><span><a href="#Lasso-Regression" data-toc-modified-id="Lasso-Regression-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Lasso Regression</a></span></li><li><span><a href="#ELastic-Net" data-toc-modified-id="ELastic-Net-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>ELastic Net</a></span></li><li><span><a href="#Random-Forest" data-toc-modified-id="Random-Forest-6.3.5"><span class="toc-item-num">6.3.5&nbsp;&nbsp;</span>Random Forest</a></span></li></ul></li></ul></li><li><span><a href="#Gerando-Predições" data-toc-modified-id="Gerando-Predições-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Gerando Predições</a></span></li></ul></div>

# %% [markdown]
# Este notebook tem como objetivo alocar o desenvolvimento prático e teórico da competição do [Kaggle](https://www.kaggle.com/) de nível iniciante: [Housing Prices - Advanced Regression Techniques](https://www.kaggle.com/c/house-prices-advanced-regression-techniques). Baseado no excelente kernel [Comprehensive data exploration with Python](https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python), de [Pedro Marcelino](https://www.kaggle.com/pmarcelino) em fevereiro de 2017, a intenção desta primeira abordagem é analisar o conjunto de dados fornecido e averiguar as relações e os insights retirados através de análises estatísticas.

# %% [markdown]
# Adicionalmente, outros kernels postados no próprio Kaggle serão utilizados como base para solução das dúvidas que surgirem durante o desenvolvimento deste projeto. De cara, é possível citar o kernel [Handling Missing Values](https://www.kaggle.com/dansbecker/handling-missing-values) do instrutor do Kaggle DanB e também o excelente kernel [Regularized Linear Models](https://www.kaggle.com/apapiu/regularized-linear-models) de Alexandro Papiu. Mãos à obra!

# %% [markdown]
# ## Introdução

# %% [markdown]
# Para facilitar o acompanhamento do projeto, o desenvolvimento será dividido em:
#
# * **1. Entendimento do problema:** Veremos a seguir que o conjunto de dados traz consigo 80 variáveis divididas entre dados numéricos e categóricos, cada qual descrevendo um atributo específico da moradia (tendo como target, o preço de venda _'SalesPrice'_). Pedro Marcelino, em seu kernel, propôs uma metodologia interessante para o entendimento do problema: para entender melhor os atributos, nada mais eficiente de que uma análise filosófica caso a caso, verificando as descrições das features, categorizando-as de acordo com funcionalidades presentes no problema de negócio e, por fim, pontuando uma análise subjetiva sobre a importância de cada uma das features para predição do target de preço. Este pacote de análises poderia ser realizado no Excel, por exemplo.

# %% [markdown]
# * **2. Estudo Univariável:** Após esse mergulho no conjunto de dados proporcionado, a ideia é analisar separadamente nossa variável target _SalesPrice_, retirando insights relacionados às conclusões obtidas no passo **1** e verificando se realmente fazem sentido.

# %% [markdown]
# * **3. Estudo Multivariável:** Objetivando o completo entendimento dos dados, será realizado uma análise contemplando todas as variáveis (dependente e independentes), averiguando correlações e dados estatísticos.

# %% [markdown]
# * **4. Suposições:** Iremos verificar numericamente se as conclusões obtidas fazem sentido para o problema de negócio proposto.

# %% [markdown]
# ## Funções Úteis

# %%
def format_spines(ax, right_border=True):
    """
    this function sets up borders from an axis and personalize colors
    """    
    # Setting up colors
    ax.spines['bottom'].set_color('#CCCCCC')
    ax.spines['left'].set_color('#CCCCCC')
    ax.spines['top'].set_visible(False)
    if right_border:
        ax.spines['right'].set_color('#CCCCCC')
    else:
        ax.spines['right'].set_color('#FFFFFF')
    ax.patch.set_facecolor('#FFFFFF')

# %% [markdown]
# ## Lendo os Dados

# %%
# Importando bibliotecas
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Lendo dados
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# Verificando dimensões
print(f'Dimensões dos dados de treino: {train.shape}')
print(f'Dimensões dos dados de teste: {test.shape}')
# Out:
# Dimensões dos dados de treino: (1460, 81)
# Dimensões dos dados de teste: (1459, 80)

# %%
# Verificando cabeçalho
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
# Verificando colunas
train.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# Pela análise do cabeçalho do conjunto de dados com o método `head()` já foi possível ter uma noção sobre dados nulos, dados categóricos, dados numéricos e qualquer outra intuição inicial obtida com essa observação. Futuramente, iremos avaliar com mais calma cada um desses subconjuntos mencionados, mas antes, é preciso expor as análises individuais propostas para cada um dos atributos contidos no conjunto.

# %% [markdown]
# ## Explorando os Dados

# %% [markdown]
# ### Pré-Análise

# %% [markdown]
# Vejamos o procedimento adotado e alguns dos insights retirados.

# %%
# Lendo csv com dados sobre os atributos levantados nessa pré-análise
pre_analise = pd.read_csv('pre_analise_utf.txt', sep=';', index_col='nome_variavel')
pre_analise.head()
# Out:
#                                                    descricao        tipo  \
# nome_variavel
# MSSubClass        Identifica o tipo de moradia da residência  Categórico
# MSZoning                        Classifica o imóvel por zona  Categórico
# LotFrontage            Dimensão do perímetro frontal da casa    Numérico
# LotArea                                   Área do loteamento    Numérico
# Street         Característica da rua que dá acesso a moradia  Categórico
#
#                              segmento expect
# nome_variavel
# MSSubClass      Building (Construção)  Média
# MSZoning       Location (Localização)   Alta
# LotFrontage            Space (Espaço)   Alta
# LotArea                Space (Espaço)   Alta
# Street          Building (Construção)  Média

# %% [markdown]
# Tendo estes dados em mãos, as análises futuras se tornam extremamente mais fáceis, visto que, neste momento, é possível ter como referência um local de consulta que, mesmo apresentando certo viés subjetivo, contempla observações sobre o problema do ponto de vista do cliente/usuário do modelo. Um dos pontos principais dessa análise está relacionado a categorização de features com possível _Alta_ importância pro algoritmo (foram designadas 20 no total) e precisamos saber se isso realmente faz sentido.

# %% [markdown]
# ### Dados Nulos

# %% [markdown]
# Dando início às análises via código, vamos estudar um pouco sobre os atributos nulos contidos neste conjunto de dados.

# %%
# Quantidade de dados nulos
train_total_null = train.isnull().sum().sum()
train_qtd_attr_null = train.isnull().any().sum()
test_total_null = test.isnull().sum().sum()
test_qtd_attr_null = test.isnull().any().sum()

# Comunicando
print(f'Atributos com dados nulos (treino): {train_qtd_attr_null}')
print(f'Total de entradas nulas (treino): {train_total_null}')
print(f'\nAtributos com dados nulos (teste): {test_qtd_attr_null}')
print(f'Total de entradas nulas (teste): {test_total_null}')
# Out:
# Atributos com dados nulos (treino): 19
# Total de entradas nulas (treino): 6965
#
# Atributos com dados nulos (teste): 33
# Total de entradas nulas (teste): 7000

# %% [markdown]
# Com relação a quantidade, temos praticamente o mesmo número de entradas nulas para treino e para teste. Quanto ao total de atirbutos com entradas nulas, o conjunto de teste apresenta um número significativamente maior. Vejamos detalhes sobre tais atributos.

# %%
# Analisando atributos nulos nos dados de treino
null_attr_train = [attr for attr, null in train.isnull().any().items() if null]
print(null_attr_train, end=',')
print(f'\n\nQuantidade: {len(null_attr_train)}')
# Out:
# ['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature'],
#
# Quantidade: 19

# %%
# Analisando atributos nulos nos dados de teste
null_attr_test = [attr for attr, null in test.isnull().any().items() if null]
print(null_attr_test, end=',')
print(f'\n\nQuantidade: {len(null_attr_test)}')
# Out:
# ['MSZoning', 'LotFrontage', 'Alley', 'Utilities', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType'],
#
# Quantidade: 33

# %%
# Detalhes da pré-análise sobre dados nulos
qtd_null_train = [qtd for qtd in train.isnull().sum().values if qtd > 0]
analise_null = pre_analise.loc[null_attr_train, :]
analise_null['qtd_null'] = qtd_null_train
analise_null.sort_values(by='qtd_null', ascending=False)
# Out:
#                                                        descricao        tipo  \
# nome_variavel
# PoolQC                                      Qualidade da piscina  Categórico
# MiscFeature    Algumas features não inclusas nas demais categ...  Categórico
# Alley            Característica da viela que dá acesso a moradia  Categórico
# Fence                   Qualidade do cercado presente na moradia  Categórico
# FireplaceQu                               Qualidade das lareiras  Categórico
# LotFrontage                Dimensão do perímetro frontal da casa    Numérico
# GarageType                            Tipo de garagem da moradia  Categórico
# GarageYrBlt                         Ano de construção da garagem    Numérico
# GarageFinish                       Acabamento interno da garagem  Categórico
# GarageQual                                  Qualidade da garagem  Categórico
# GarageCond              Score que define as condições da garagem  Categórico
# BsmtExposure                       Exposição do porão da moradia  Categórico
# BsmtFinType2   Score do acabamento da região relacionada ao p...  Categórico
# BsmtFinType1   Score do acabamento da região relacionada ao p...  Categórico
# BsmtCond                      Classifica condição geral do porão  Categórico
# BsmtQual         Classifica a moradia quanto ao tamanho do porão  Categórico
# MasVnrArea                           Área coberta pela alvenaria  Categórico
# MasVnrType                           Tipo de alvenaria utilizada  Categórico
# Electrical                      Tipo de sistema elétrico da casa  Categórico
#
#                             segmento expect  qtd_null
# nome_variavel
# PoolQC         Building (Construção)  Média      1453
# MiscFeature    Building (Construção)  Baixa      1406
# Alley          Building (Construção)  Baixa      1369
# Fence          Building (Construção)  Baixa      1179
# FireplaceQu    Building (Construção)  Baixa       690
# LotFrontage           Space (Espaço)   Alta       259
# GarageType            Space (Espaço)   Alta        81
# GarageYrBlt    Building (Construção)  Baixa        81
# GarageFinish   Building (Construção)  Baixa        81
# GarageQual     Building (Construção)  Baixa        81
# GarageCond     Building (Construção)  Baixa        81
# BsmtExposure   Building (Construção)  Baixa        38
# BsmtFinType2   Building (Construção)  Baixa        38
# BsmtFinType1   Building (Construção)  Média        37
# BsmtCond       Building (Construção)  Média        37
# BsmtQual              Space (Espaço)  Baixa        37
# MasVnrArea     Building (Construção)  Baixa         8
# MasVnrType     Building (Construção)  Baixa         8
# Electrical     Building (Construção)  Média         1

# %% [markdown]
# **Diagnóstico:**
#
# Temos quantidades diferentes de entradas nulas nos dois conjuntos de dados disponíveis (treino e teste). A pré-análise irá auxiliar na decisão sobre o tratamento destes dados nulos de acordo com características como _quantidade_, _expectativa (influência)_ e _tipo primitivo_.

# %% [markdown]
# Neste momento, antes de avaliar as possíveis decisões com maior profundidade, vamos analisar um ponto importante: os atributos _Categóricos_.

# %% [markdown]
# #### Atributos Categóricos

# %%
# Indexando atributos categóricos
cat_train_attribs = [attr for attr, dtype in train.dtypes.items() if dtype == 'object']
cat_test_attribs = [attr for attr, dtype in test.dtypes.items() if dtype == 'object']

# Verificando
cat_train_attribs == cat_test_attribs
# Out:
# True

# %% [markdown]
# Vamos somar o total de quantidade de entradas dos dois conjuntos

# %%
# Aplicando somatório
total_train_cat_entries = 0
for attr in cat_train_attribs:
    total_train_cat_entries += len(train[attr].value_counts())
    
print(f'Total de entradas categóricas nos dados de treino: {total_train_cat_entries}')
# Out:
# Total de entradas categóricas nos dados de treino: 252

# %%
# Aplicando somatório
total_test_cat_entries = 0
for attr in cat_test_attribs:
    total_test_cat_entries += len(test[attr].value_counts())
    
print(f'Total de entradas categóricas nos dados de treino: {total_test_cat_entries}')
# Out:
# Total de entradas categóricas nos dados de treino: 234

# %% [markdown]
# Eis um grande problema! Pensando já nas tratativas dos atributos categóricos para o treinamento do modelo, a aplicação da classe `One Hot Encoder` do scikit-learn transforma uma feature categórica em `n` novas features de acordo com a quantidade `n` de entradas. Vejamos essa quantidade `n` por atributo.

# %%
# Criando análise com dados de treino e teste
cat_entries_info = pd.DataFrame({})
cat_train_list = []
train_null = []
cat_test_list = []
test_null = []
for attr in cat_train_attribs:
    cat_train_list.append(len(train[attr].value_counts()))
    cat_test_list.append(len(test[attr].value_counts()))
    train_null.append(train[attr].isnull().sum())
    test_null.append(test[attr].isnull().sum())

# Adicionando dados e configurando dataframe
cat_entries_info['qtd_train_entries'] = cat_train_list
cat_entries_info['qtd_null_train'] = train_null
cat_entries_info['qtd_test_entries'] = cat_test_list
cat_entries_info['qtd_null_test'] = test_null
cat_entries_info['diff'] = cat_entries_info['qtd_train_entries'] - \
cat_entries_info['qtd_test_entries']
cat_entries_info.index = cat_train_attribs

# Verificando
cat_entries_info.head()
# Out:
#              qtd_train_entries  qtd_null_train  qtd_test_entries  \
# MSZoning                     5               0                 5
# Street                       2               0                 2
# Alley                        2            1369                 2
# LotShape                     4               0                 4
# LandContour                  4               0                 4
#
#              qtd_null_test  diff
# MSZoning                 4     0
# Street                   0     0
# Alley                 1352     0
# LotShape                 0     0
# LandContour              0     0

# %%
# Adicionando influência da pré análise
expect_cat = pre_analise.loc[cat_entries_info.index, ['expect']].values
cat_entries_info['expect'] = expect_cat

# Visualizando
cat_entries_info.sort_values(by='qtd_null_train', ascending=False, inplace=True)
cat_entries_info
# Out:
#                qtd_train_entries  qtd_null_train  qtd_test_entries  \
# PoolQC                         3            1453                 2
# MiscFeature                    4            1406                 3
# Alley                          2            1369                 2
# Fence                          4            1179                 4
# FireplaceQu                    5             690                 5
# GarageType                     6              81                 6
# GarageCond                     5              81                 5
# GarageQual                     5              81                 4
# GarageFinish                   3              81                 3
# BsmtFinType2                   6              38                 6
# BsmtExposure                   4              38                 4
# BsmtFinType1                   6              37                 6
# BsmtQual                       4              37                 4
# BsmtCond                       4              37                 4
# MasVnrType                     4               8                 4
# Electrical                     5               1                 4
# Functional                     7               0                 7
# KitchenQual                    4               0                 4
# CentralAir                     2               0                 2
# HeatingQC                      5               0                 5
# Heating                        6               0                 4
# PavedDrive                     3               0                 3
# SaleType                       9               0                 9
# MSZoning                       5               0                 5
# Street                         2               0                 2
# Condition2                     8               0                 5
# LotShape                       4               0                 4
# LandContour                    4               0                 4
# Utilities                      2               0                 1
# LotConfig                      5               0                 5
# LandSlope                      3               0                 3
# Neighborhood                  25               0                25
# Condition1                     9               0                 9
# BldgType                       5               0                 5
# Foundation                     6               0                 6
# HouseStyle                     8               0                 7
# RoofStyle                      6               0                 6
# RoofMatl                       8               0                 4
# Exterior1st                   15               0                13
# Exterior2nd                   16               0                15
# ExterQual                      4               0                 4
# ExterCond                      5               0                 5
# SaleCondition                  6               0                 6
#
#                qtd_null_test  diff expect
# PoolQC                  1456     1  Média
# MiscFeature             1408     1  Baixa
# Alley                   1352     0  Baixa
# Fence                   1169     0  Baixa
# FireplaceQu              730     0  Baixa
# GarageType                76     0   Alta
# GarageCond                78     0  Baixa
# GarageQual                78     1  Baixa
# GarageFinish              78     0  Baixa
# BsmtFinType2              42     0  Baixa
# BsmtExposure              44     0  Baixa
# BsmtFinType1              42     0  Média
# BsmtQual                  44     0  Baixa
# BsmtCond                  45     0  Média
# MasVnrType                16     0  Baixa
# Electrical                 0     1  Média
# Functional                 2     0  Média
# KitchenQual                1     0   Alta
# CentralAir                 0     0   Alta
# HeatingQC                  0     0   Alta
# Heating                    0     2   Alta
# PavedDrive                 0     0  Baixa
# SaleType                   1     0  Baixa
# MSZoning                   4     0   Alta
# Street                     0     0  Média
# Condition2                 0     3  Baixa
# LotShape                   0     0  Média
# LandContour                0     0  Baixa
# Utilities                  2     1   Alta
# LotConfig                  0     0  Baixa
# LandSlope                  0     0  Baixa
# Neighborhood               0     0  Baixa
# Condition1                 0     0  Média
# BldgType                   0     0  Média
# Foundation                 0     0   Alta
# HouseStyle                 0     1  Média
# RoofStyle                  0     0  Média
# RoofMatl                   0     4    NaN
# Exterior1st                1     2  Baixa
# Exterior2nd                1     1  Baixa
# ExterQual                  0     0   Alta
# ExterCond                  0     0   Alta
# SaleCondition              0     0  Baixa

# %% [markdown]
# Temos alguns problemas:
#
# * Atributos com grandes quantidades de dados nulos;
# * Atributos com diferenças na quantidade de entradas entre os conjuntos de treino e teste (diff > 0);
#
# **Solução 1:** Deletar todos os atributos categóricos que não tenham _alta_ influência no target e com diferença de entradas entre os dados de treino e teste, evitando problemas com o _one hot encoder_. O preenchimento dos dados nulos dos atributos restantes (se existirem) será dado pelas entradas mais comuns.;
#
# **Solução 2:** Deletar atributos categóricos com presença de dados nulos em uma quantidade acima de um threshold a ser determinado, independente da influência no target. O preenchimento dos dados nulos seria dado pela entrada mais comum;

# %% [markdown]
# Seguindo a primeira solução, ficaríamos apenas com os atributos _ExterQual_, _ExterCond_, _MSZoning_, _KitchenQual_, _CentralAir_, _HeatingQC_ e _GarageType_.

# %% [markdown]
# ##### Filtrando Atributos

# %%
# Atributos categóricos mantidos
keep_cat_df = cat_entries_info.query('expect == "Alta" & diff == 0')
drop_cat_df = cat_entries_info.query('expect != "Alta"')
keep_cat_df
# Out:
#              qtd_train_entries  qtd_null_train  qtd_test_entries  \
# GarageType                   6              81                 6
# KitchenQual                  4               0                 4
# CentralAir                   2               0                 2
# HeatingQC                    5               0                 5
# MSZoning                     5               0                 5
# Foundation                   6               0                 6
# ExterQual                    4               0                 4
# ExterCond                    5               0                 5
#
#              qtd_null_test  diff expect
# GarageType              76     0   Alta
# KitchenQual              1     0   Alta
# CentralAir               0     0   Alta
# HeatingQC                0     0   Alta
# MSZoning                 4     0   Alta
# Foundation               0     0   Alta
# ExterQual                0     0   Alta
# ExterCond                0     0   Alta

# %% [markdown]
# **Solução 1.1:** Preencher os dados nulos com as entradas mais comuns.
#
# **Solução 1.2:** Deletar instâncias com dados nulos.

# %%
# Filtrando colunas
drop_cat = drop_cat_df.index
train_cat_attr_filtered = train.drop(drop_cat, axis=1)

# Levantando atributos categóricos
definitive_cat_attr = [attr for attr, dtype in train_cat_attr_filtered.dtypes.items() if dtype == 'object']

# Verificando dimensões
print(f'Dataset original: {train.shape}')
print(f'Dataset filtrado: {train_cat_attr_filtered.shape}')
print(f'Total de atributos categóricos excluídos: {len(drop_cat)}')

print(f'Valores batem? {len(drop_cat) == train.shape[1] - train_cat_attr_filtered.shape[1]}')
# Out:
# Dataset original: (1460, 81)
# Dataset filtrado: (1460, 48)
# Total de atributos categóricos excluídos: 33
# Valores batem? True

# %%
# Criando função para selecionar atributos numéricos e categóricos (facilitando implementação)
def filter_attribs(X, cat=True):
    """
    seleciona os atributos de acordo com seu tipo primitivo e retorna uma lista como resultado
    """
    if cat:
        attribs = [attr for attr, dtype in X.dtypes.items() if dtype == 'object']
    else:
        attribs = [attr for attr, dtype in X.dtypes.items() if dtype != 'object']
    
    return attribs

# %%
# Testando função
new_cat_attribs = filter_attribs(train_cat_attr_filtered)

# Verificando se batem
print(f'Colunas categóricas (sem função): {len(definitive_cat_attr)}')
print(f'Colunas categóricas (após função): {len(new_cat_attribs)}')
print(f'Números batem? {len(definitive_cat_attr) == len(new_cat_attribs)}')
# Out:
# Colunas categóricas (sem função): 10
# Colunas categóricas (após função): 10
# Números batem? True

# %% [markdown]
# ##### Preenchendo Dados Nulos

# %% [markdown]
# Como informado anteriormente, o preenchimento dos dados nulos será dado pelas entradas mais comuns dentro dos atributos categóricos.

# %%
# Filtrando atributos que possuem dados nulos
X = train_cat_attr_filtered.copy()
X_cat = X.loc[:, definitive_cat_attr]
X_cat.isnull().any()[X_cat.isnull().any().values].index
# Out:
# Index(['GarageType'], dtype='object')

# %% [markdown]
# De fato, depois da filtragem dos atributos categóricos, temos apenas `GarageType` contendo dados nulos. Vamos analisa-lo melhor.

# %%
# Vamos analisar se é viável manter GarageType dados a quantidade de nulos
X['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
# Retornando a entrada mais comum
most_common = X['GarageType'].value_counts().index[0]
most_common
# Out:
# 'Attchd'

# %%
# Preenchendo
X['GarageType'] = X[['GarageType']].fillna(value=most_common)

# %%
# Verificando se ainda existem dados nulos
X_cat = X.loc[:, definitive_cat_attr]
X_cat.isnull().any()[X_cat.isnull().any().values].index
# Out:
# Index([], dtype='object')

# %%
# Criando classe para ser implementada futuramente em um pipeline
from sklearn.base import BaseEstimator, TransformerMixin

class fillCategoricalNullValues(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        # Retornando colunas com dados nulos
        null_cat_attr = list(X.isnull().any()[X.isnull().any().values].index)
        
        # Retornando entradas mais comuns de cada um deles
        fill_data = {}
        for attr in null_cat_attr:
            most_common = X[attr].value_counts().index[0]
            fill_data[attr] = most_common
        
        # Preenchendo dados nulos
        new_X = X.fillna(value=fill_data)
            
        return new_X

# %%
# Testando
filler = fillCategoricalNullValues()
X_cat = train_cat_attr_filtered.loc[:, definitive_cat_attr]
X_filled = filler.transform(X_cat)

# Verificando
X_filled['GarageType'].isnull().any()
# Out:
# False

# %%
# Analisando como foi feito o preenchimento
X_cat['GarageType'].value_counts()
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %%
# Quantidade que deveria ser preenchida na entrada "Attchd"
garage_null = X_cat["GarageType"].isnull().sum()
garage_most_common = X_cat["GarageType"].value_counts().values[0]
print(f'Quantidade de nulos em GarageType: {garage_null}')
print(f'Quantidade inicial da entrada mais comum: {garage_most_common}')
print(f'Quantidade esperada final no atributo mais comum: {garage_most_common + garage_null}')
# Out:
# Quantidade de nulos em GarageType: 81
# Quantidade inicial da entrada mais comum: 870
# Quantidade esperada final no atributo mais comum: 951

# %%
# Tirando prova
X_filled['GarageType'].value_counts()
# Out:
# Attchd     951
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %% [markdown]
# Perfeito! Definimos nosso pipeline para filtrar e tratar dados nulos em atributos categóricos. Vejamos agora os procedimentos que serão realizados para os atributos numéricos.

# %% [markdown]
# #### Atributos Numéricos

# %%
# Filtrando atributos numéricos com a nova função criada
num_attribs = filter_attribs(train, cat=False)
cat_attribs = filter_attribs(train)
print(f'Quantidade de atributos numéricos (original): {len(num_attribs)}')
print(f'Quantidade de atributos categóricos (original): {len(cat_attribs)}')
print(f'Total sem alterações já realizadas: {train.shape[1]}')
# Out:
# Quantidade de atributos numéricos (original): 38
# Quantidade de atributos categóricos (original): 43
# Total sem alterações já realizadas: 81

# %%
# Verificando alguns
num_attribs[:5]
# Out:
# ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual']

# %% [markdown]
# Com os atributos numéricos devidamente indexados, vamos agora visualizar a correlação com o target `SalesPrice`. Para isso, vamos avaliar o índice de correlação por código e compará-lo a nossa análise inicial.

# %%
# Indexando dataframe
target = train['SalePrice']
X_num = train.loc[:, num_attribs]

# %%
# Verificando dados nulos
X_num.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# LotFrontage      259
# LotArea            0
# OverallQual        0
# OverallCond        0
# YearBuilt          0
# YearRemodAdd       0
# MasVnrArea         8
# BsmtFinSF1         0
# BsmtFinSF2         0
# BsmtUnfSF          0
# TotalBsmtSF        0
# 1stFlrSF           0
# 2ndFlrSF           0
# LowQualFinSF       0
# GrLivArea          0
# BsmtFullBath       0
# BsmtHalfBath       0
# FullBath           0
# HalfBath           0
# BedroomAbvGr       0
# KitchenAbvGr       0
# TotRmsAbvGrd       0
# Fireplaces         0
# GarageYrBlt       81
# GarageCars         0
# GarageArea         0
# WoodDeckSF         0
# OpenPorchSF        0
# EnclosedPorch      0
# 3SsnPorch          0
# ScreenPorch        0
# PoolArea           0
# MiscVal            0
# MoSold             0
# YrSold             0
# SalePrice          0
# dtype: int64

# %%
# Indexando dados nulos
null_num_attribs = X_num.isnull().any()[X_num.isnull().any().values].index
null_num_attribs
# Out:
# Index(['LotFrontage', 'MasVnrArea', 'GarageYrBlt'], dtype='object')

# %%
# Verificando estatísticas
for null_attrib in null_num_attribs:
    print(f'Àtributo: {null_attrib}')
    print(X_num[null_attrib].describe())
    print()
# Out:
# Àtributo: LotFrontage
# count    1201.000000
# mean       70.049958
# std        24.284752
# min        21.000000
# 25%        59.000000
# 50%        69.000000
# 75%        80.000000
# max       313.000000
# Name: LotFrontage, dtype: float64
#
# Àtributo: MasVnrArea
# count    1452.000000
# mean      103.685262
# std       181.066207
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       166.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64
#
# Àtributo: GarageYrBlt
# count    1379.000000
# mean     1978.506164
# std        24.689725
# min      1900.000000
# 25%      1961.000000
# 50%      1980.000000
# 75%      2002.000000
# max      2010.000000
# Name: GarageYrBlt, dtype: float64

# %% [markdown]
# ##### Preenchendo Dados Nulos

# %% [markdown]
# Temos apenas 3 atributos numéricos com dados nulos em suas entradas. É papel do cientista de dados definir a melhor forma de tratar estes dados nulos. Em uma primeira abordagem, vamos definir um pipeline de preenchimento de dados nulos (atributos numéricos) com a mediana do conjunto.

# %%
# Criando imputer
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='median')
imputer.fit(X_num)
X_num_imputed = pd.DataFrame(imputer.transform(X_num), columns=X_num.columns)

# %%
# Verificando
X_num_imputed.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# LotFrontage      0
# LotArea          0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# MasVnrArea       0
# BsmtFinSF1       0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# TotRmsAbvGrd     0
# Fireplaces       0
# GarageYrBlt      0
# GarageCars       0
# GarageArea       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SalePrice        0
# dtype: int64

# %% [markdown]
# ### Correlações

# %% [markdown]
# Vamos realizar algumas análises relacionadas ao target do modelo (`SalePrice`)

# %%
# Estatística
target.describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# **Análise:**
#
# * O valor mínimo é maior que 0, ou seja, não é necessário de preocupar com particularidades durante a construção do modelo;

# %%
# Distribuição
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

fig, ax = plt.subplots(figsize=(10, 4))
ax = sns.distplot(target, bins=40)
format_spines(ax)
ax.set_title('Distribuição SalePrice', size=14)
plt.show()

# %%
# Métricas de similaridade
skewness = target.skew()
kurtosis = target.kurt()
print(f'Skewness: {skewness:.4f}')
print(f'Kurtosis: {kurtosis:.4f}')
# Out:
# Skewness: 1.8829
# Kurtosis: 6.5363

# %% [markdown]
# **Análise:**
#
# * A variável target difere da distribuição normal
# * Temos as medidas de Skewness ([Assimetria](https://pt.wikipedia.org/wiki/Assimetria_(estat%C3%ADstica)) ou Obliquidade) e Kurtosis ([Curtose](https://pt.wikipedia.org/wiki/Curtose) ou Achatamento) que indicam:
#     * [Skewness](https://en.wikipedia.org/wiki/Skewness)
#         * positivo: long tail à direita;
#         * negativo: long tail à esquerda;
#         * igual a 0: distribuição aproximadamente simétrica.
#     * [Kurtosis](https://en.wikipedia.org/wiki/Kurtosis)
#         * igual a 3: achatamento de uma distribuição normal;
#         * maior que 3: distribuição mais alta (afunilada);
#         * menor que 3: distribuição mais achatada que a normal.

# %% [markdown]
# Segundo o usuário _deja vu_ em seu kernel [House Prices: EDA to ML (Beginner)](https://www.kaggle.com/dejavu23/house-prices-eda-to-ml-beginner), a falta de simetria na distribuição do target `SalePrice` pode reduzir a performance do modelo de Machine Learning, dado que os modelos de regressão assumem uma distribuição normal. Utilizando funcionalidades do `numpy`, é possível aplicar uma transformação logarítimica nos dados. Vejamos:

# %%
# Transformando
import numpy as np

target_log = np.log(target)
fig, ax = plt.subplots(figsize=(10, 4))
ax = sns.distplot(target_log, bins=40)
format_spines(ax)
ax.set_title('Distribuição SalePrice (Log)', size=14)
plt.show()

# Comunicando métricas skewness e kurtosis
print(f'Skewness: {target_log.skew():.4f}')
print(f'Kurtosis: {target_log.kurt():.4f}')
# Out:
# Skewness: 0.1213
# Kurtosis: 0.8095

# %% [markdown]
# Experiência: se aplicássemos uma técnica de normalização (`StandardScaler`), teríamos resultado semelhante?

# %%
# Testando
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
target_scaled = target.copy()
target_scaled = scaler.fit_transform(pd.DataFrame(target_scaled))

# Plotando
fig, ax = plt.subplots(figsize=(10, 4))
ax = sns.distplot(target_scaled, bins=40)
format_spines(ax)
ax.set_title('Distribuição SalePrice (Scaled)', size=14)
plt.show()

# Comunicando métricas skewness e kurtosis
print(f'Skewness: {pd.Series(list(target_scaled)).skew():.4f}')
print(f'Kurtosis: {pd.Series(list(target_scaled)).kurt():.4f}')
# Out:
# Skewness: 1.8829
# Kurtosis: 6.5363

# %% [markdown]
# Com a análise a partir dos dados padronizados, obtivemos a mesma curva e as mesmas métricas obtidas com os dados sem nenhum tratamento.

# %% [markdown]
# Vamos agora retornar os atributos numéricos e analisar a influência estabelecida na pré-análise

# %%
# Pré-Análise
num_pre_analise = pre_analise.loc[num_attribs]
num_pre_analise.drop(['Id', 'SalePrice'], inplace=True)
num_pre_analise
# Out:
#                                                        descricao        tipo  \
# nome_variavel
# MSSubClass            Identifica o tipo de moradia da residência  Categórico
# LotFrontage                Dimensão do perímetro frontal da casa    Numérico
# LotArea                                       Área do loteamento    Numérico
# OverallQual            Score do material e acabamento da moradia  Categórico
# OverallCond                   Score da condição geral da moradia  Categórico
# YearBuilt                              Ano de construção da casa    Numérico
# YearRemodAdd   Ano de remodelação da casa (mesmo que YearBuil...    Numérico
# MasVnrArea                           Área coberta pela alvenaria  Categórico
# BsmtFinSF1     Área coberta pelo acabamento do tipo 1 (atribu...    Numérico
# BsmtFinSF2     Área coberta pelo acabamento do tipo 2 (atribu...    Numérico
# BsmtUnfSF                           Área do porão sem acabamento    Numérico
# TotalBsmtSF                                  Área total do porão    Numérico
# 1stFlrSF                 Área total do primeiro andar da moradia    Numérico
# 2ndFlrSF                  Área total do segundo andar da moradia    Numérico
# LowQualFinSF   Área total de acabamentos de baixa qualidade e...    Numérico
# GrLivArea                            Área total da sala de estar    Numérico
# BsmtFullBath   Banheiros completos (full) da área relacionada...    Numérico
# BsmtHalfBath   Banheiros incompletos (half) da área relaciona...    Numérico
# FullBath       Quantidade de banheiros completos na casa (aci...    Numérico
# HalfBath       Quantidade de banheiros incompletos (half) na ...    Numérico
# BedroomAbvGr     Quantidade de camas na moradia (acima do porão)    Numérico
# KitchenAbvGr   Quantidade de cozinhas na moradia (acima do po...    Numérico
# TotRmsAbvGrd   Quantidade total de quartos na moradia (acima ...    Numérico
# Fireplaces                     Quantidade de lareiras da moradia    Numérico
# GarageYrBlt                         Ano de construção da garagem    Numérico
# GarageCars     Tamanho da garagem relacionado a quantidade de...    Numérico
# GarageArea                   Área da garagem em metros quadrados    Numérico
# WoodDeckSF           Área do deck de madeira presente na moradia    Numérico
# OpenPorchSF                    Área de varanda aberta na moradia    Numérico
# EnclosedPorch                 Área de varanda fechada na moradia    Numérico
# 3SsnPorch                 Área de varande de três temporadas (?)    Numérico
# ScreenPorch                   Área de tela na varanda da moradia    Numérico
# PoolArea                     Área de piscina presente na moradia    Numérico
# MiscVal        Valor das features não inclusas em critérios d...    Numérico
# MoSold              Mês no qual a venda da moradia foi efetivada    Numérico
# YrSold              Ano no qual a venda da moradia foi efetivada    Numérico
#
#                             segmento expect
# nome_variavel
# MSSubClass     Building (Construção)  Média
# LotFrontage           Space (Espaço)   Alta
# LotArea               Space (Espaço)   Alta
# OverallQual    Building (Construção)   Alta
# OverallCond    Building (Construção)   Alta
# YearBuilt      Building (Construção)   Alta
# YearRemodAdd   Building (Construção)  Média
# MasVnrArea     Building (Construção)  Baixa
# BsmtFinSF1     Building (Construção)  Baixa
# BsmtFinSF2     Building (Construção)  Baixa
# BsmtUnfSF      Building (Construção)  Baixa
# TotalBsmtSF           Space (Espaço)  Média
# 1stFlrSF              Space (Espaço)   Alta
# 2ndFlrSF              Space (Espaço)   Alta
# LowQualFinSF          Space (Espaço)  Baixa
# GrLivArea             Space (Espaço)  Média
# BsmtFullBath          Space (Espaço)  Baixa
# BsmtHalfBath          Space (Espaço)  Baixa
# FullBath              Space (Espaço)  Média
# HalfBath              Space (Espaço)  Baixa
# BedroomAbvGr          Space (Espaço)   Alta
# KitchenAbvGr          Space (Espaço)   Alta
# TotRmsAbvGrd          Space (Espaço)   Alta
# Fireplaces            Space (Espaço)  Média
# GarageYrBlt    Building (Construção)  Baixa
# GarageCars            Space (Espaço)  Média
# GarageArea            Space (Espaço)  Média
# WoodDeckSF            Space (Espaço)  Média
# OpenPorchSF           Space (Espaço)  Média
# EnclosedPorch         Space (Espaço)  Média
# 3SsnPorch             Space (Espaço)  Baixa
# ScreenPorch           Space (Espaço)  Média
# PoolArea              Space (Espaço)  Média
# MiscVal        Building (Construção)  Baixa
# MoSold                Space (Espaço)  Baixa
# YrSold                Space (Espaço)  Baixa

# %%
# Indexando somente atributos com alta influência
high_corr_pre_analise = num_pre_analise.query('expect == "Alta"')
high_corr_pre_analise
# Out:
#                                                        descricao        tipo  \
# nome_variavel
# LotFrontage                Dimensão do perímetro frontal da casa    Numérico
# LotArea                                       Área do loteamento    Numérico
# OverallQual            Score do material e acabamento da moradia  Categórico
# OverallCond                   Score da condição geral da moradia  Categórico
# YearBuilt                              Ano de construção da casa    Numérico
# 1stFlrSF                 Área total do primeiro andar da moradia    Numérico
# 2ndFlrSF                  Área total do segundo andar da moradia    Numérico
# BedroomAbvGr     Quantidade de camas na moradia (acima do porão)    Numérico
# KitchenAbvGr   Quantidade de cozinhas na moradia (acima do po...    Numérico
# TotRmsAbvGrd   Quantidade total de quartos na moradia (acima ...    Numérico
#
#                             segmento expect
# nome_variavel
# LotFrontage           Space (Espaço)   Alta
# LotArea               Space (Espaço)   Alta
# OverallQual    Building (Construção)   Alta
# OverallCond    Building (Construção)   Alta
# YearBuilt      Building (Construção)   Alta
# 1stFlrSF              Space (Espaço)   Alta
# 2ndFlrSF              Space (Espaço)   Alta
# BedroomAbvGr          Space (Espaço)   Alta
# KitchenAbvGr          Space (Espaço)   Alta
# TotRmsAbvGrd          Space (Espaço)   Alta

# %% [markdown]
# É notável que alguns atributos, na pré-análise, foram classificados como Categóricos quando, na verdade, foram designados via código ao grupo dos atributos numéricos. Um dos fatores que podem ter levado a essa conclusão diz respeito ao significado real do atributo, dado que, em alguns casos, temos números inteiros indicando categorias (1 = 'A', 2 = 'B'), fazendo com que, por linha de código, esses atributos tenham sido caracterizados como Numérico quando, na verdade, traduzem informações categóricas.

# %% [markdown]
# Vejamos uma matriz de correlação para entender melhor a situação dos atributos numéricos.

# %%
# Matriz de correlação
corrmat = train.corr()
fig, ax = plt.subplots(figsize=(12, 8))
sns.heatmap(corrmat, vmax=.8, square=True)

# %% [markdown]
# Antes de comentar sobre o resultado obtido com a matriz acima, é necessário entender que:
# * Quadrados claros indicam uma forte correlação positiva;
# * Quadrados escuros indicam uma forte correlação negativa.

# %% [markdown]
# **1º ponto:** forte correlação positiva entre os atributos `TotalBsmtSF` e `1stFlrSF`

# %%
# Vejamos do que se trata esses atributos
pre_analise.loc[['TotalBsmtSF', '1stFlrSF']]
# Out:
#                                              descricao      tipo  \
# nome_variavel
# TotalBsmtSF                        Área total do porão  Numérico
# 1stFlrSF       Área total do primeiro andar da moradia  Numérico
#
#                      segmento expect
# nome_variavel
# TotalBsmtSF    Space (Espaço)  Média
# 1stFlrSF       Space (Espaço)   Alta

# %% [markdown]
# **2º ponto:** forte correlação positiva entre os atributos `GarageCars` e `GarageArea`

# %%
# Vejamos em mais detalhes
pre_analise.loc[['GarageCars', 'GarageArea']]
# Out:
#                                                        descricao      tipo  \
# nome_variavel
# GarageCars     Tamanho da garagem relacionado a quantidade de...  Numérico
# GarageArea                   Área da garagem em metros quadrados  Numérico
#
#                      segmento expect
# nome_variavel
# GarageCars     Space (Espaço)  Média
# GarageArea     Space (Espaço)  Média

# %% [markdown]
# **Análise:**
#
# * Essa forte correlação positiva entre atributos indica uma situação de _multicolinearidade_. Isso indica que, possivelmente, tais atributos podem estar representando a mesma informação, o que indesejável para o modelo.
#
# * Um outro ponto extremamente importante diz respeito às variáveis que possuem alta correlação com nosso target `SalePrice`, sendo estas: `OverallQual`, `GrLivarea`, `GarageCars`, `GarageArea` e mais algumas.

# %%
corrmat.nlargest(10, 'SalePrice')['SalePrice'].index
# Out:
# Index(['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'GarageArea',
#        'TotalBsmtSF', '1stFlrSF', 'FullBath', 'TotRmsAbvGrd', 'YearBuilt'],
#       dtype='object')

# %%
# Top 10 atributos com maior correlação com o target
k = 10
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
fig, ax = plt.subplots(figsize=(18, 7))
ax = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 12}, 
                 yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# Vejamos se, na pré-análise realizada, conseguimos captar o que os dados acabaram de nos informar

# %%
# Resultado da pré análise
pre_analise.loc[cols[1:]]
# Out:
#                                                       descricao        tipo  \
# OverallQual           Score do material e acabamento da moradia  Categórico
# GrLivArea                           Área total da sala de estar    Numérico
# GarageCars    Tamanho da garagem relacionado a quantidade de...    Numérico
# GarageArea                  Área da garagem em metros quadrados    Numérico
# TotalBsmtSF                                 Área total do porão    Numérico
# 1stFlrSF                Área total do primeiro andar da moradia    Numérico
# FullBath      Quantidade de banheiros completos na casa (aci...    Numérico
# TotRmsAbvGrd  Quantidade total de quartos na moradia (acima ...    Numérico
# YearBuilt                             Ano de construção da casa    Numérico
#
#                            segmento expect
# OverallQual   Building (Construção)   Alta
# GrLivArea            Space (Espaço)  Média
# GarageCars           Space (Espaço)  Média
# GarageArea           Space (Espaço)  Média
# TotalBsmtSF          Space (Espaço)  Média
# 1stFlrSF             Space (Espaço)   Alta
# FullBath             Space (Espaço)  Média
# TotRmsAbvGrd         Space (Espaço)   Alta
# YearBuilt     Building (Construção)   Alta

# %% [markdown]
# Bom, não podemos dizer que tivemos um aproveitamento de 100%, entretando ao menos tivemos o bom senso de indicar influência `Média` a alguns atributos com influência `Alta`. Analisando individualmente estes atributos, temos:
#
# * **OverallQual:** Ok. Mencionamos, em tópicos anteriores, que este atributo poderia ser muito importante para a análise;
# * **GrLivArea:** A sala de estar realmente importa para a construção do preço da casa e sua respectiva venda. Faz sentido.
# * **GarageCars** e **GarageArea**: Aparentemente o espaço proporcionado pela garagem causa bastante influência no preço de venda da casa. Porém, como discutido acima, ambos são atributos com alta correlação entre si, dado que a área calculada da garagem é baseada na quantidade de carros que esta comporta. Podemos simplesmente manter o atributo GarageCars, uma vez que sua correlação com o target SalePrice é maior.
# * **TotalBsmtSF** e **1stFlrSF**: Assim como no caso acima, ambos são atributos com alta correlação entre si. Iremos manter TotalBsmtSF com a mesma justificativa do tópico logo acima.
# * **FullBath:** Ok, de certa forma isso era esperado. A quantidade de banheiros em uma casa realmente possui influência em seu preço de venda;
# * **TotRmsAbvGrd:** Também trazendo total sentido, a quantidade de quartos é importante para o cálculo do preço da casa.
# * **YearBuilt:** Também concordo que o ano de construção da casa pode influenciar em seu preço.

# %% [markdown]
# TODO
#
#     - Plotar pairplot com correlações de todas as variáveis;
#     - Analisar resultados (https://www.kaggle.com/pmarcelino/comprehensive-data-exploration-with-python);
#     - Verificar necessidade de tratar outliers nessa primeira abordagem;
#     - Analisar transformações logaritmicas nos dados;
#     - Entender plotagem probabilística (Theoretical Quantiles x Ordered Values);
#     - Criar pipeline de transformação;
#     - Treinar modelo;
#     - Analisar resultados.

# %% [markdown]
# ## Pipeline

# %% [markdown]
# A partir da análise exploratória aplicada aos dados, podemos definir um pipeline de transformação para auxiliar na preparação dos dados em uma forma concisa e eficiente.

# %%
# Lendo novamente os dados para evitar qualquer transformação já realizada
X_train = pd.read_csv('train.csv')
X_test = pd.read_csv('test.csv')

# Target
y_train = X_train['SalePrice']
X_train.drop('SalePrice', axis=1, inplace=True)

# Verificando
X_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... ScreenPorch PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 1         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 2         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 3         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
# 4         Lvl    AllPub  ...           0        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0       0      2    2008        WD         Normal
# 1       0      5    2007        WD         Normal
# 2       0      9    2008        WD         Normal
# 3       0      2    2006        WD        Abnorml
# 4       0     12    2008        WD         Normal
#
# [5 rows x 80 columns]

# %% [markdown]
# ### Pipeline Categórico

# %%
# Importando bibliotecas
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder

# Defininindo atributos categóricos
cat_attribs = ['GarageType', 'KitchenQual', 'CentralAir', 'HeatingQC', 'MSZoning', 'Foundation', 'ExterQual',
               'ExterCond']
X_cat = X_train.loc[:, cat_attribs]

# Criando pipeline categórico
cat_pipeline = Pipeline([
    ('filler', fillCategoricalNullValues()),
    ('encoder', OneHotEncoder(sparse=False))
])

# %%
# Testando
X_cat_prepared = cat_pipeline.fit_transform(X_cat)

# Verificando
print(f'Dimensões dos dados antes da preparação: {X_cat.shape}')
print(f'Dimensões dos dados após a preparação: {X_cat_prepared.shape}')
# Out:
# Dimensões dos dados antes da preparação: (1460, 8)
# Dimensões dos dados após a preparação: (1460, 37)

# %% [markdown]
# ### Pipeline Numérico

# %%
# Definindo atributos numéricos
num_attribs = filter_attribs(train, cat=False)
num_attribs = num_attribs[1:-1]

X_num = X_train.loc[:, num_attribs]

# Criando pipeline numérico
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# %%
# Testando
X_num_prepared = num_pipeline.fit_transform(X_num)

# Verificando
X_num_prepared[0]
# Out:
# array([ 0.07337496, -0.22087509, -0.20714171,  0.65147924, -0.51719981,
#         1.05099379,  0.87866809,  0.51410389,  0.57542484, -0.28865283,
#        -0.94459061, -0.45930254, -0.79343379,  1.16185159, -0.12024172,
#         0.37033344,  1.10781015, -0.24106104,  0.78974052,  1.22758538,
#         0.16377912, -0.21145358,  0.91220977, -0.95122649,  1.01759808,
#         0.31172464,  0.35100032, -0.75217584,  0.21650316, -0.3593249 ,
#        -0.11633929, -0.27020835, -0.06869175, -0.08768781, -1.5991111 ,
#         0.13877749])

# %% [markdown]
# ### Pipeline Completo

# %% [markdown]
# Juntando as duas etapas

# %%
# Importando bibliotecas
from sklearn.compose import ColumnTransformer

#  Definições iniciais
cat_attribs = ['GarageType', 'KitchenQual', 'CentralAir', 'HeatingQC', 'MSZoning', 'Foundation', 'ExterQual',
               'ExterCond']
num_attribs = filter_attribs(train, cat=False)
num_attribs = num_attribs[1:-1]

X_cat = X_train.loc[:, cat_attribs]
X_num = X_train.loc[:, num_attribs]

# Criando pipeline numérico
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Criando pipeline categórico
cat_pipeline = Pipeline([
    ('filler', fillCategoricalNullValues()),
    ('encoder', OneHotEncoder(sparse=False))
])

# Criando pipeline completo
full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', cat_pipeline, cat_attribs)
])

# Preparando os dados
X_train_prepared = full_pipeline.fit_transform(X_train)

# %%
# Verificando
print(f'Dimensões antes da preparação: {X_train.shape}')
print(f'Dimensões após a preparação; {X_train_prepared.shape}')
# Out:
# Dimensões antes da preparação: (1460, 80)
# Dimensões após a preparação; (1460, 73)

# %% [markdown]
# ## Treinando um Modelo

# %% [markdown]
# ### Primeira Abordagem

# %% [markdown]
# Com os dados preparados, podemos estudar implementações para esta primeira abordagem.

# %%
# Importando bibliotecas para métricas
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error

# Preparando dados de teste para futuras avaliações
X_test_prepared = full_pipeline.fit_transform(X_test)

# %% [markdown]
# #### Linear Regression

# %%
# Importando regressor
from sklearn.linear_model import LinearRegression

# Treinando modelo
lin_reg = LinearRegression()
lin_reg.fit(X_train_prepared, y_train)

# Validando (treino)
train_pred = lin_reg.predict(X_train_prepared)
train_score = np.sqrt(mean_squared_error(train_pred, y_train))
print(f'RMSE nos dados de treino: {train_score}')
# Out:
# RMSE nos dados de treino: 31950.314797621686

# %%
# Aplicando validação cruzada
lin_reg_scores = cross_val_score(lin_reg, X_train_prepared, y_train, cv=5, scoring='neg_mean_squared_error')
lin_reg_cv_score = np.sqrt(-lin_reg_scores).mean()
lin_reg_cv_score
# Out:
# 116464418173650.45

# %% [markdown]
# TODO:
#
#     - Investigar os motivos do resultado ter sido EXTREMAMENTE PÉSSIMO na validação cruzada!

# %% [markdown]
# #### Decision Trees Regressor

# %%
# Importando regressor
from sklearn.tree import DecisionTreeRegressor

# Treinando modelo
tree_reg = DecisionTreeRegressor()
tree_reg.fit(X_train_prepared, y_train)

# Avaliando modelo
tree_pred = tree_reg.predict(X_train_prepared)
tree_rmse = np.sqrt(mean_squared_error(y_train, tree_pred))
print(f'RMSE Decision Trees Regressor: {tree_rmse}')
# Out:
# RMSE Decision Trees Regressor: 153.59839111600309

# %% [markdown]
# Como sabemos, os modelos de Árvores de Decisão tendem ao Overfitting dos dados. O "excelente" score obtido acima não deve ser puramente levado em consideração, dado que aplicamos uma simples predição com os próprios dados de treino para o modelo. Para avaliar o real comportamento do modelo de Árvore de Decisão, precisamos aplicar a `validação cruzada`.

# %%
# Aplicando cross validation
tree_scores = cross_val_score(tree_reg, X_train_prepared, y_train, cv=5, scoring='neg_mean_squared_error')
tree_cv_score = np.sqrt(-tree_scores).mean()
tree_cv_score
# Out:
# 40735.93050873076

# %% [markdown]
# #### Random Forest

# %%
# Importando biblioteca
from sklearn.ensemble import RandomForestRegressor

# Treinando modelo
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train_prepared, y_train)

# Avaliando modelo
forest_pred = forest_reg.predict(X_train_prepared)
forest_score = np.sqrt(mean_squared_error(y_train, forest_pred))
print(f'RMSE Random Forest Regressor: {forest_score}')
# Out:
# RMSE Random Forest Regressor: 13086.30340093444

# %% [markdown]
# Vejamos após a validação cruzada

# %%
# Aplicando validação cruzada
forest_scores = cross_val_score(forest_reg, X_train_prepared, y_train, cv=5, scoring='neg_mean_squared_error')
forest_cv_score = np.sqrt(-forest_scores).mean()
forest_cv_score
# Out:
# 32355.446802138562

# %% [markdown]
# #### SVR Regressor

# %%
# Importando biblioteca
from sklearn.svm import SVR

# Treinando modelo
svr = SVR()
svr.fit(X_train_prepared, y_train)

# Avaliando modelo
svr_pred = svr.predict(X_train_prepared)
svr_score = mean_squared_error(y_train, svr_pred)
print(f'RMSE SVR Regressor: {svr_score}')
# Out:
# RMSE SVR Regressor: 6616564124.379491

# %%
# Aplicando validação cruzada
svr_scores = cross_val_score(svr, X_train_prepared, y_train, cv=5, scoring='neg_mean_squared_error')
svr_score = np.sqrt(-svr_scores).mean()
svr_score
# Out:
# 81109.85237236328

# %% [markdown]
# De acordo com os resultados obtidos, é possível concluir que provavelmente todos os modelos irão apresentar um melhor score a partir da busca com Grid Search CV. Vamos aplicá-lo, a princípio no algoritmo de Random Forest

# %% [markdown]
# #### Grid Search CV

# %%
# Buscando a melhor combinação para RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Definindo parâmetros
param_grid = [
    {'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]},
]

# Criando regressor
forest_reg = RandomForestRegressor()

# Treinando e procurando a melhor combinação
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_prepared, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# Verificando scores de cada combinação
results = grid_search.cv_results_
for mean_score, params in zip(results['mean_test_score'], results['params']):
    print(np.sqrt(-mean_score), params)
# Out:
# 31248.78117487096 {'max_features': 10, 'n_estimators': 30}
# 30583.025230792657 {'max_features': 10, 'n_estimators': 40}
# 30208.822041397787 {'max_features': 10, 'n_estimators': 50}
# 29586.80882579703 {'max_features': 10, 'n_estimators': 75}
# 30428.052042452433 {'max_features': 10, 'n_estimators': 90}
# 29025.965252258895 {'max_features': 12, 'n_estimators': 30}
# 29939.258010196012 {'max_features': 12, 'n_estimators': 40}
# 29347.50400191311 {'max_features': 12, 'n_estimators': 50}
# 29918.525101136907 {'max_features': 12, 'n_estimators': 75}
# 29249.503648921735 {'max_features': 12, 'n_estimators': 90}
# 29633.731294887966 {'max_features': 15, 'n_estimators': 30}
# 30198.97690302455 {'max_features': 15, 'n_estimators': 40}
# 28873.47461883266 {'max_features': 15, 'n_estimators': 50}
# 30269.807775099824 {'max_features': 15, 'n_estimators': 75}
# 29266.484194329187 {'max_features': 15, 'n_estimators': 90}
# 30531.40107990175 {'max_features': 20, 'n_estimators': 30}
# 30302.332480719924 {'max_features': 20, 'n_estimators': 40}
# 29320.536990918972 {'max_features': 20, 'n_estimators': 50}
# 29428.41462329563 {'max_features': 20, 'n_estimators': 75}
# 29177.84286247275 {'max_features': 20, 'n_estimators': 90}
# 29202.495531946413 {'max_features': 25, 'n_estimators': 30}
# 29007.60441604099 {'max_features': 25, 'n_estimators': 40}
# 30221.6625890284 {'max_features': 25, 'n_estimators': 50}
# 29707.987584552382 {'max_features': 25, 'n_estimators': 75}
# 29488.553482025545 {'max_features': 25, 'n_estimators': 90}

# %% [markdown]
# Após algumas tentativas, é razoável dizer que os scores realmente ficam em torno de 29.000, o que pode ser considerado alto.

# %% [markdown]
# #### Feature Importance

# %%
feature_importances = grid_search.best_estimator_.feature_importances_
cat_encoder = full_pipeline.named_transformers_['cat'].named_steps['encoder']
cat_one_hot_attribs = list(cat_encoder.categories_[0])
atributos = num_attribs + cat_one_hot_attribs
sorted(zip(feature_importances, atributos), reverse=True)
# Out:
# [(0.2309828885309702, 'OverallQual'),
#  (0.09198022983228617, 'GrLivArea'),
#  (0.07863711719577182, 'GarageCars'),
#  (0.07129327163535645, 'TotalBsmtSF'),
#  (0.05354701877172191, 'GarageArea'),
#  (0.0517499972751718, 'YearBuilt'),
#  (0.038358083444783794, '2ndFlrSF'),
#  (0.03663236521910002, '1stFlrSF'),
#  (0.03376421981953088, 'BsmtFinSF1'),
#  (0.03266651853404431, 'FullBath'),
#  (0.021983163198553736, 'GarageYrBlt'),
#  (0.019777525617283225, 'LotArea'),
#  (0.014811832617591992, 'TotRmsAbvGrd'),
#  (0.014729600455073702, 'MasVnrArea'),
#  (0.013618379875817004, 'YearRemodAdd'),
#  (0.012997083920314996, 'Fireplaces'),
#  (0.012113661191847792, 'LotFrontage'),
#  (0.00880633298428666, 'BsmtUnfSF'),
#  (0.007442903999541943, 'OpenPorchSF'),
#  (0.005712514672949945, 'BedroomAbvGr'),
#  (0.00564204947005905, 'MSSubClass'),
#  (0.005445447895457961, 'WoodDeckSF'),
#  (0.0048637077175019, 'MoSold'),
#  (0.004465649618750488, 'OverallCond'),
#  (0.004179615492697929, 'HalfBath'),
#  (0.0032658261675163665, 'BsmtFullBath'),
#  (0.0027570306697920453, 'YrSold'),
#  (0.00228672819473717, 'Attchd'),
#  (0.0017973665597072175, 'ScreenPorch'),
#  (0.0017605580200724315, 'PoolArea'),
#  (0.0016735413380817071, 'Detchd'),
#  (0.0013645525356415689, 'BuiltIn'),
#  (0.0013423027960419525, 'KitchenAbvGr'),
#  (0.001284337132918037, 'EnclosedPorch'),
#  (0.0009568818063875472, 'BsmtFinSF2'),
#  (0.0009230073411536873, 'BsmtHalfBath'),
#  (0.00038618051993602855, 'MiscVal'),
#  (0.00033497770155579623, 'LowQualFinSF'),
#  (0.00018337673366864346, '3SsnPorch'),
#  (0.0001078007610152086, 'Basment'),
#  (9.292886475205051e-05, 'CarPort'),
#  (8.156603151835172e-05, '2Types')]

# %% [markdown]
# ### Segunda Abordagem

# %% [markdown]
# Filtrando apenas atributos numéricos com correlação alta com o target SalePrice.

# %%
# Top 10 atributos com maior correlação com o target
k = 10
cols = corrmat.nlargest(k, 'SalePrice')['SalePrice'].index
cm = np.corrcoef(train[cols].values.T)
sns.set(font_scale=1.25)
fig, ax = plt.subplots(figsize=(18, 7))
ax = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 12}, 
                 yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
#  Definições iniciais
cat_attribs = ['GarageType', 'KitchenQual', 'CentralAir', 'HeatingQC', 'MSZoning', 'Foundation', 'ExterQual',
               'ExterCond']
num_attribs = cols[1:]

X_cat = X_train.loc[:, cat_attribs]
X_num = X_train.loc[:, num_attribs]

# Criando pipeline numérico
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())
])

# Criando pipeline categórico
cat_pipeline = Pipeline([
    ('filler', fillCategoricalNullValues()),
    ('encoder', OneHotEncoder(sparse=False))
])

# Criando pipeline completo
full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', cat_pipeline, cat_attribs)
])

# Preparando os dados
X_train_prepared = full_pipeline.fit_transform(X_train)

# %%
# Treinando modelo
# Importando biblioteca
from sklearn.ensemble import RandomForestRegressor

# Treinando modelo
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train_prepared, y_train)

# Avaliando modelo
forest_pred = forest_reg.predict(X_train_prepared)
forest_score = np.sqrt(mean_squared_error(y_train, forest_pred))
print(f'RMSE Random Forest Regressor: {forest_score}')

# Validação cruzada
forest_scores = cross_val_score(forest_reg, X_train_prepared, y_train, cv=5, scoring='neg_mean_squared_error')
forest_cv_score = np.sqrt(-forest_scores).mean()
print(f'RMSE Cross Validation Random Forest: {forest_cv_score}')
# Out:
# RMSE Random Forest Regressor: 16319.029254807296
# RMSE Cross Validation Random Forest: 32986.16159861583

# %%
# Buscando a melhor combinação para RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Definindo parâmetros
param_grid = [
    {'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]},
]

# Criando regressor
forest_reg = RandomForestRegressor()

# Treinando e procurando a melhor combinação
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_prepared, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# Melhor score
forest_best_score = np.sqrt(-grid_search.best_score_)
forest_best_score
# Out:
# 30982.19627142233

# %% [markdown]
# A conclusão final para esta segunda abordagem é a de que, mesmo selecionando apenas os atributos com maiores índices de correlação com nosso target `SalePrice`, não foi possível obter melhores resultados através do treinamento com o algoritmo `RandomForest`. A partir disso, vamos tentar uma terceira abordagem com o objetivo de aumentar definitivamente o score rmse.

# %% [markdown]
# ### Terceira Abordagem

# %% [markdown]
# Após toda a preparação dos dados e dos insights iniciais relacionados aos treinamentos de modelos de Regressão, vamos agora aplicar uma transformação nos dados que, de certa forma, já foi mencionada anteriormente nos tópicos de preparação: **transformação logaritma**.

# %%
# Vejamos algumas distribuições
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.distplot(target)
format_spines(ax, right_border=False)
ax.set_title('Distribuição SalePrice', size=15)
plt.show()

# %%
# Aplicando transformação logarítima
target_log = np.log(target+1)
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.distplot(target_log)
format_spines(ax, right_border=False)
ax.set_title('Distribuição Logarítima SalePrice', size=15)
plt.show()

# %% [markdown]
# Vejamos estes efeitos em algumas outras variáveis

# %%
# Aplicando transformação logarítima
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))

attribute = X_num['GrLivArea']
log_attribute = np.log(attribute+1)

sns.distplot(attribute, ax=axs[0])
format_spines(axs[0], right_border=False)
skew = attribute.skew()
kurt = attribute.kurt()
axs[0].set_title(f'GrLivArea \nSkew: {skew:.4f}, Kurt: {kurt:.4f}', size=15)

sns.distplot(log_attribute, ax=axs[1])
format_spines(axs[1], right_border=False)
log_skew = log_attribute.skew()
log_kurt = log_attribute.kurt()
axs[1].set_title(f'Log GrLivArea\n Skew: {log_skew:.4f}, Kurt: {log_kurt:.4f}', size=15)
plt.show()

# %% [markdown]
# **Lembrando:**
#
# * Temos as medidas de Skewness ([Assimetria](https://pt.wikipedia.org/wiki/Assimetria_(estat%C3%ADstica)) ou Obliquidade) e Kurtosis ([Curtose](https://pt.wikipedia.org/wiki/Curtose) ou Achatamento) que indicam:
#     * [Skewness](https://en.wikipedia.org/wiki/Skewness)
#         * positivo: long tail à direita;
#         * negativo: long tail à esquerda;
#         * igual a 0: distribuição aproximadamente simétrica.
#     * [Kurtosis](https://en.wikipedia.org/wiki/Kurtosis)
#         * igual a 3: achatamento de uma distribuição normal;
#         * maior que 3: distribuição mais alta (afunilada);
#         * menor que 3: distribuição mais achatada que a normal.

# %% [markdown]
# Segundo o usuário _deja vu_ em seu kernel [House Prices: EDA to ML (Beginner)](https://www.kaggle.com/dejavu23/house-prices-eda-to-ml-beginner), a falta de simetria na distribuição do target `SalePrice` pode reduzir a performance do modelo de Machine Learning, dado que os modelos de regressão assumem uma distribuição normal. Utilizando funcionalidades do `numpy`, é possível aplicar uma transformação logarítimica nos dados. Vejamos:

# %%
# Verificando em todos os atributos
fig, axs = plt.subplots(nrows=9, ncols=2, figsize=(12, 25))
columns = list(X_num.columns)
i = 0

for col in columns:
    # Calculando parâmetros
    attribute = X_num[col]
    skew = attribute.skew()
    kurt = attribute.kurt()
    log_attribute = np.log1p(attribute)
    log_skew = log_attribute.skew()
    log_kurt = log_attribute.kurt()
    
    # Plotando gráficos
    sns.distplot(attribute, ax=axs[i, 0])
    sns.distplot(log_attribute, ax=axs[i, 1])
    
    # Configurando plotagens
    attr_name = columns[i]
    format_spines(axs[i, 0], right_border=False)
    format_spines(axs[i, 1], right_border=False)
    axs[i, 0].set_title(f'{attr_name}\n Skew:{skew:.4f}, Kurt:{kurt:.4f}')
    axs[i, 1].set_title(f'{attr_name}\n Skew:{log_skew:.4f}, Kurt:{log_kurt:.4f}')
    i += 1

plt.tight_layout()
plt.show()

# %%
# Criando classe para transformação logarítima
class logTransformation(BaseEstimator, TransformerMixin):
    
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        return np.log1p(X)

# %%
# Importando bibliotecas
from sklearn.compose import ColumnTransformer

#  Definições iniciais
cat_attribs = ['GarageType', 'KitchenQual', 'CentralAir', 'HeatingQC', 'MSZoning', 'Foundation', 'ExterQual',
               'ExterCond']
num_attribs = cols[1:]

X_cat = X_train.loc[:, cat_attribs]
X_num = X_train.loc[:, num_attribs]

# Aplicando log
X_num_log = np.log(X_num)

# Criando pipeline numérico
num_pipeline = Pipeline([
    ('imputer', SimpleImputer(strategy='median')),
    ('log', logTransformation()),
    #('scaler', StandardScaler()),
])

# Criando pipeline categórico
cat_pipeline = Pipeline([
    ('filler', fillCategoricalNullValues()),
    ('encoder', OneHotEncoder(sparse=False))
])

# Criando pipeline completo
full_pipeline = ColumnTransformer([
    ('num', num_pipeline, num_attribs),
    ('cat', cat_pipeline, cat_attribs)
])

# Preparando os dados
X_train_prepared = full_pipeline.fit_transform(X_train)
target_log = np.log1p(target)

# %% [markdown]
# Antes de realizar o treinamento dos modelos, vamos criar uma função para armazenar os scores obtidos ao longo dos testes. Dessa forma, será possível comparar alguns parâmetros de modo a selecionar o melhor modelo para este nosso problema de negócio.

# %% [markdown]
# #### Linear Regression

# %%
# Treinando modelo com regressão linear
lin_reg = LinearRegression()
lin_reg.fit(X_train_prepared, target_log)

# Cross validation
lin_reg_scores = cross_val_score(lin_reg, X_train_prepared, target_log, cv=5, scoring='neg_mean_squared_error')
lin_reg_cv_score = np.sqrt(-lin_reg_scores).mean()
lin_reg_cv_score
# Out:
# 0.15416111667778398

# %% [markdown]
# Excelente! Um resultado bem melhor do que o obtido anteriormente. Vamos testar com outros modelos.

# %% [markdown]
# #### Ridge Regression

# %% [markdown]
# Também conhecida como _Tikhonov Regulariation_, o modelo de Ridge Regression é uma forma regularizada da Regressão Linear com um termo de regularização igual a:
#
# \begin{equation*}
#     \alpha\sum_{i=1}^{n}\theta_i^2 \text{ = }l_2 \text{ penalty}
# \end{equation*}

# %% [markdown]
# Este termo, adicionado a `função custo`, força o modelo a não apenas se enquadrar aos dados, mas também manter os `pesos` do modelo tão baixos quanto possível. Este termo de regularização somente deve ser adicionado a função custo durante o treinamento. Uma vez treinado o modelo, sua performance deve ser medida sem regularização.

# %% [markdown]
# \begin{equation*}
#     J(\theta)=MSE(\theta) + \alpha\frac{1}{2}\sum_{i=1}^{n}\theta_i^2
# \end{equation*}

# %% [markdown]
# \begin{equation*}
#     \begin{cases}
#         \alpha = 0 & \mbox{Ridge Regression = Linear Regression} \\
#         \alpha = alto & \mbox{Alta penalização nos pesos e redução no overfitting} \\
#         \alpha = baixo & \mbox{Baixa penalização nos pesos e aumento do underfitting}
#     \end{cases}
# \end{equation*}

# %% [markdown]
# É importante aplicar a `normalização` dos dados _(Standard Scaler)_ antes de performar o modelo Ridge Regression!

# %% [markdown]
# O termo de regularização aplicado representa uma penalidade do tipo $l_2$ que, por sua vez, tem como principal característica a penalização elevada _(quadrado)_ a medida que a magnitude dos parâmetros são altas. [l1_l2_penalties](https://towardsdatascience.com/l1-and-l2-regularization-methods-ce25e7fc831c)

# %%
# Aplicando modelos
from sklearn.linear_model import Ridge

# Treinando modelo
ridge_reg = Ridge(alpha=1, solver='cholesky')
ridge_reg.fit(X_train_prepared, target_log)
# Cross validation
ridge_reg_scores = cross_val_score(ridge_reg, X_train_prepared, target_log, cv=5, scoring='neg_mean_squared_error')
ridge_reg_cv_score = np.sqrt(-ridge_reg_scores).mean()
ridge_reg_cv_score
# Out:
# 0.15426890415411182

# %%
# Definindo função para facilitar o cálculo da validação cruzada
def calc_rmse(model, X, y, cv=5, scoring='neg_mean_squared_error'):
    scores = cross_val_score(model, X, y, cv=cv, scoring=scoring)
    return np.sqrt(-scores).mean()

# %%
calc_rmse(ridge_reg, X_train_prepared, target_log)
# Out:
# 0.15426890415411182

# %%
alphas = [0.001, 0.003, 0.01, 0.03, 0.05, 0.1, 0.3, 1, 3, 5, 10, 15, 30, 50, 75]
ridge_scores = []
for a in alphas:
    ridge_scores.append(calc_rmse(Ridge(alpha=a), X_train_prepared, target_log))

# %%
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(alphas, ridge_scores)
format_spines(ax, right_border=False)
ax.set_title('Parâmetros Alpha - Ridge Regression')
plt.show()

# %%
# Melhor resultado
best_ridge_rmse = min(ridge_scores)
best_ridge_alpha = alphas[ridge_scores.index(best_ridge_rmse)]

print(f'Melhor score RMSE: {best_ridge_rmse} com alpha = {best_ridge_alpha}')
# Out:
# Melhor score RMSE: 0.15415814586578785 com alpha = 0.003

# %% [markdown]
# #### Lasso Regression

# %% [markdown]
# Também conhecido como _Least Absolut Shrinkage and Selection Operator Regression_ e simplesmente chamado de _Lasso Regression_ é uma outra versão da Regressão Linear, também adicionando um termo de regularização à função custo.

# %% [markdown]
# \begin{equation*}
#     J(\theta)=MSE(\theta) + \alpha\sum_{i=1}^{n}|\theta_i|
# \end{equation*}

# %% [markdown]
# Diferente do Ridge Regression, o Lasso Regression aplica uma `penalização` do tipo $l_1$ que, por sua vez, faz com que os coeficientes das features de menor importância tenham tendência a `zerar`. Portanto, é possível dizer que este tipo de penalidade pode atuar bem como uma `feature selection` no caso de haver muitas features.

# %%
# Importando regressor
from sklearn.linear_model import Lasso

lasso_reg = Lasso()
calc_rmse(lasso_reg, X_train_prepared, target_log)
# Out:
# 0.39922568603836983

# %%
# Verificando regularização
alphas = [0.0001, 0.0003, 0.001, 0.003, 0.005]
lasso_scores = []
for a in alphas:
    lasso_scores.append(calc_rmse(Lasso(alpha=a), X_train_prepared, target_log))
    
fig, ax = plt.subplots(figsize=(10, 5))
ax = sns.lineplot(alphas, lasso_scores)
format_spines(ax, right_border=False)
ax.set_title('Parâmetros Alpha - Lasso Regression')
plt.show()

# %%
# Melhor resultado
best_lasso_rmse = min(lasso_scores)
best_lasso_alpha = alphas[lasso_scores.index(best_lasso_rmse)]

print(f'Melhor score RMSE: {best_lasso_rmse} com alpha = {best_lasso_alpha}')
# Out:
# Melhor score RMSE: 0.15417228983524112 com alpha = 0.0003

# %% [markdown]
# #### ELastic Net

# %% [markdown]
# Podemos dizer que o modelo Elatic Net é um meio termo entre o Ridge Regression e o Lasso Regressio. Seu termo de regularização é uma `mistura` entre ambos citados anteriormente e é possível controlar a taxa de mistura `r`.
#
# * Quando $r=0$, o Elastic Net é equivalente ao Ridge Regression
# * Quando $r=1$, o Elastic Net é equivalente ao Lasso Regression

# %% [markdown]
# \begin{equation*}
#     J(\theta)=MSE(\theta) + r\alpha\sum_{i=1}^n|\theta_i|+
#               \frac{1-r}{2}\alpha\sum_{i=1}^n\theta_i^2
# \end{equation*}

# %%
# Importando biblioteca e treinando
from sklearn.linear_model import ElasticNet

elastic_reg = ElasticNet()
calc_rmse(elastic_reg, X_train_prepared, target_log)
# Out:
# 0.39922568603836983

# %%
# Verificando melhor modelo
alphas = [0.001, 0.01, 0.03, 0.05, 0.1, 0.3]
ratios = np.logspace(0, 1, 10)/10
elastic_analysis = pd.DataFrame({})
cols = ['rmse', 'alpha', 'l1_ratio']
for col in cols:
    elastic_analysis[col] = []
performances = {}

for alpha in alphas:
    for l1_ratio in ratios:
        score = calc_rmse(ElasticNet(alpha=alpha, l1_ratio=l1_ratio), X_train_prepared, target_log)
        performances['rmse'] = score
        performances['alpha'] = alpha
        performances['l1_ratio'] = l1_ratio
        elastic_analysis = elastic_analysis.append(performances, ignore_index=True)

# %%
elastic_analysis
# Out:
#         rmse  alpha  l1_ratio
# 0   0.154241  0.001  0.100000
# 1   0.154232  0.001  0.129155
# 2   0.154231  0.001  0.166810
# 3   0.154199  0.001  0.215443
# 4   0.154134  0.001  0.278256
# 5   0.154095  0.001  0.359381
# 6   0.154092  0.001  0.464159
# 7   0.154050  0.001  0.599484
# 8   0.154070  0.001  0.774264
# 9   0.154308  0.001  1.000000
# 10  0.157591  0.010  0.100000
# 11  0.158096  0.010  0.129155
# 12  0.158836  0.010  0.166810
# 13  0.159944  0.010  0.215443
# 14  0.161264  0.010  0.278256
# 15  0.162357  0.010  0.359381
# 16  0.163828  0.010  0.464159
# 17  0.166023  0.010  0.599484
# 18  0.169578  0.010  0.774264
# 19  0.175008  0.010  1.000000
# 20  0.168329  0.030  0.100000
# 21  0.169770  0.030  0.129155
# 22  0.171623  0.030  0.166810
# 23  0.174254  0.030  0.215443
# 24  0.178034  0.030  0.278256
# 25  0.183726  0.030  0.359381
# 26  0.190649  0.030  0.464159
# 27  0.199641  0.030  0.599484
# 28  0.211095  0.030  0.774264
# 29  0.222623  0.030  1.000000
# 30  0.177153  0.050  0.100000
# 31  0.179946  0.050  0.129155
# 32  0.183885  0.050  0.166810
# 33  0.189354  0.050  0.215443
# 34  0.195996  0.050  0.278256
# 35  0.204661  0.050  0.359381
# 36  0.215898  0.050  0.464159
# 37  0.227628  0.050  0.599484
# 38  0.244167  0.050  0.774264
# 39  0.264147  0.050  1.000000
# 40  0.198247  0.100  0.100000
# 41  0.204484  0.100  0.129155
# 42  0.212624  0.100  0.166810
# 43  0.222649  0.100  0.215443
# 44  0.235047  0.100  0.278256
# 45  0.249045  0.100  0.359381
# 46  0.269214  0.100  0.464159
# 47  0.292641  0.100  0.599484
# 48  0.326253  0.100  0.774264
# 49  0.350942  0.100  1.000000
# 50  0.262631  0.300  0.100000
# 51  0.276548  0.300  0.129155
# 52  0.294142  0.300  0.166810
# 53  0.315239  0.300  0.215443
# 54  0.339788  0.300  0.278256
# 55  0.356017  0.300  0.359381
# 56  0.366507  0.300  0.464159
# 57  0.377725  0.300  0.599484
# 58  0.390264  0.300  0.774264
# 59  0.399226  0.300  1.000000

# %%
# Melhor combinação
elastic_analysis.iloc[elastic_analysis['rmse'].argmin(), :]
# Out:
# rmse        0.154050
# alpha       0.001000
# l1_ratio    0.599484
# Name: 7, dtype: float64

# %% [markdown]
# #### Random Forest

# %%
# Importando biblioteca
from sklearn.ensemble import RandomForestRegressor

# Treinando modelo
forest_reg = RandomForestRegressor()
forest_reg.fit(X_train_prepared, target_log)

# Avaliando modelo
forest_pred = forest_reg.predict(X_train_prepared)
forest_score = np.sqrt(mean_squared_error(target_log, forest_pred))
print(f'RMSE Random Forest Regressor: {forest_score}')
# Out:
# RMSE Random Forest Regressor: 0.06664004241475903

# %% [markdown]
# Vejamos após a validação cruzada

# %%
# Aplicando validação cruzada
calc_rmse(forest_reg, X_train_prepared, target_log)
# Out:
# 0.16217232599837286

# %%
# Buscando a melhor combinação para RandomForestRegressor
from sklearn.model_selection import GridSearchCV

# Definindo parâmetros
param_grid = [
    {'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]},
]

# Criando regressor
forest_reg = RandomForestRegressor()

# Treinando e procurando a melhor combinação
grid_search = GridSearchCV(forest_reg, param_grid, cv=5, scoring='neg_mean_squared_error')
grid_search.fit(X_train_prepared, target_log)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#            oob_score=False, random_state=None, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid=[{'n_estimators': [30, 40, 50, 75, 90], 'max_features': [10, 12, 15, 20, 25]}],
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
# Verificando scores de cada combinação
best_forest_rmse = np.sqrt(-grid_search.best_score_)
best_forest_rmse
# Out:
# 0.15141636699621414

# %% [markdown]
# ## Gerando Predições

# %%
# Passando dados de teste no pipeline de preparação
X_test_prepared = full_pipeline.fit_transform(test)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test_prepared)

# %%
# Gerando arquivo
submission = pd.DataFrame()
submission['Id'] = test['Id']
submission['SalePrice'] = np.exp(y_pred)
submission.to_csv('submission.csv', index=False)

# %%
# Verificando
submission.head()
# Out:
#      Id      SalePrice
# 0  1461  122047.178623
# 1  1462  154484.310881
# 2  1463  170285.208063
# 3  1464  192969.168438
# 4  1465  210000.864934
